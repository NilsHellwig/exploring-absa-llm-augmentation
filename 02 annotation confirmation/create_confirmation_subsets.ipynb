# %% [markdown]
# # Notebook: Create Confirmation Subsets

# %% [markdown]
# ## Packages

# %%
import pandas as pd
import json

# %% [markdown]
# ## Settings

# %%
N_PARTS = 2

# %%
INPUT_PATH = "annotations_nils_total_dataset.csv"
OUTPUT_PATH_PREFIX = "annotation_confirmation/annotation_confirmation_real"

# %% [markdown]
# ## Code

# %%
# Zuvor muss ich meine Annotationen hochladen roh, aus label studio als csv
df = pd.read_csv(INPUT_PATH)
df["second_annotator_comment"] = None

# %%
df["two_or_more_sentences"].unique()
# Out:
# array([nan, 'Two or more sentences'], dtype=object)

# %%
def merge_labels_implicit_to_explicit(dataframe):
    # Benutzerdefinierte Funktion, um label-implicit zu label-explicit hinzuzufügen und 'type' hinzufügen
    def merge_labels(row):
        labels_explicit = row["label-explicit"]
        labels_implicit = row["label-implicit"]

        if isinstance(labels_explicit, str) == False:
            labels_explicit = []
        else:
            labels_explicit = json.loads(labels_explicit)

        if isinstance(labels_implicit, str) == False:
            labels_implicit = []
        else:
            labels_implicit = json.loads(labels_implicit)

        labels_total = ""
        for annotation in labels_implicit:
            tuple = (annotation["labels"][0][:-len("-no-phrase")].rsplit('-', 1)[0],
                     annotation["labels"][0][:-len("-no-phrase")].rsplit('-', 1)[-1], 'NULL')
            labels_total += str(tuple) + "\n"

        for annotation in labels_explicit:
            tuple = (annotation["labels"][0].rsplit('-', 1)[0],
                     annotation["labels"][0].rsplit('-', 1)[-1], annotation["text"])
            labels_total += str(tuple) + "\n"

        row["annotation"] = labels_total

        # Sonderfälle
        # Update: Text is a bit misleading - my fault... However, I wanted to mark examples with mentioned aspects towards which no sentiment
        # was expressed by the author.
        if row["aspect_available_without_judgement"] == 'An aspect is addressed in the text without an explicit mention by the author':
            row["aspect_available_without_judgement"] = "✅"
        else:
            row["aspect_available_without_judgement"] = ""

        if row["two_or_more_sentences"] == "Two or more sentences":
            row["annotation"] = "⚠️ Mehr als 1 Satz im Text identifiziert von Annoator A"

        row["second_annotator_comment"] = ""
        return row

    dataframe = dataframe.apply(merge_labels, axis=1)

    return dataframe

# %%
total_rows = len(df)
rows_per_part = total_rows // N_PARTS

for idx in range(N_PARTS):
    start_idx = idx * rows_per_part
    end_idx = (idx + 1) * rows_per_part if idx < N_PARTS - 1 else total_rows
    part_df = df.iloc[start_idx:end_idx]

    filename = f"{OUTPUT_PATH_PREFIX}_{idx}.csv"

    part_df = merge_labels_implicit_to_explicit(part_df)
    part_df = part_df[["id", "second_annotator_comment", "annotation", "aspect_available_without_judgement", "text"]]

    part_df.to_csv(filename, index=False)

    print(f"Part {idx} saved to '{filename}'.")
# Out:
# Part 0 saved to 'annotation_confirmation/annotation_confirmation_real_0.csv'.
# Part 1 saved to 'annotation_confirmation/annotation_confirmation_real_1.csv'.

# %%
part_df[:20]
# Out:
#                                         id second_annotator_comment  \
# 2000  acb9c5da-b48e-452c-aef5-1c01601aa251
# 2001  87903ffa-a10a-44cf-968f-a2c38f82706d
# 2002  99e6780c-eb6d-45ec-afe3-7c20d8500ac6
# 2003  2f886ca9-59c8-4789-a8a7-484fcca42b5f
# 2004  77b108e0-690c-4764-bf41-599bf1db9f8d
# 2005  93ece0ca-e705-4039-a10c-de15f39210b4
# 2006  e80e7023-2d6d-4447-9cdf-47ddf6b6d7f3
# 2007  727344a6-6c89-4b90-a399-88566e39b560
# 2008  ec460bbc-5255-4f9d-89b9-397f35f75aad
# 2009  b711b3ff-4451-419c-8f1d-7a75bfe049af
# 2010  026c2ce6-cd2a-4611-9ce0-74ff9ec903bb
# 2011  9dac78e5-77c3-42f6-be1e-594bd4adbea1
# 2012  6abb1ff8-41d6-454b-bcdc-91b290839d70
# 2013  0b181899-f405-443a-950e-aa3f8f4eab50
# 2014  ea68449b-7340-467a-ad37-ca0630def331
# 2015  f47fbef8-088a-4642-a2b0-a121ff5d2aef
# 2016  9ba7da25-6bbe-47b7-a0ba-a055a2b8abdf
# 2017  c4feca07-73ad-45c7-a09d-c0b9c182c21f
# 2018  b1f29217-23cb-4d5e-a77c-862a4d45cefd
# 2019  3006d845-fc7e-4fe7-827b-a531dc60a788
#
#                                              annotation  \
# 2000  ⚠️ Mehr als 1 Satz im Text identifiziert von A...
# 2001  ('FOOD', 'NEGATIVE', 'Garnelen')\n('FOOD', 'NE...
# 2002
# 2003  ('SERVICE', 'POSITIVE', 'Kellner*innen')\n('AM...
# 2004               ('SERVICE', 'POSITIVE', 'Service')\n
# 2005               ('SERVICE', 'NEGATIVE', 'Kellner')\n
# 2006
# 2007  ⚠️ Mehr als 1 Satz im Text identifiziert von A...
# 2008  ('FOOD', 'NEGATIVE', 'Schnitzel')\n('FOOD', 'N...
# 2009  ⚠️ Mehr als 1 Satz im Text identifiziert von A...
# 2010       ('GENERAL-IMPRESSION', 'NEGATIVE', 'NULL')\n
# 2011                  ('SERVICE', 'NEGATIVE', 'NULL')\n
# 2012           ('AMBIENCE', 'CONFLICT', 'Live Musik')\n
# 2013  ('SERVICE', 'NEGATIVE', 'Service')\n('FOOD', '...
# 2014                     ('FOOD', 'POSITIVE', 'NULL')\n
# 2015
# 2016  ⚠️ Mehr als 1 Satz im Text identifiziert von A...
# 2017
# 2018                     ('FOOD', 'POSITIVE', 'NULL')\n
# 2019       ('GENERAL-IMPRESSION', 'POSITIVE', 'NULL')\n
#
#      aspect_available_without_judgement  \
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006                                  ✅
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015                                  ✅
# 2016
# 2017                                  ✅
# 2018
# 2019
#
#                                                    text
# 2000  Man muss sich nicht wundern, wenn sich die pot...
# 2001  Sowohl Hähnchenfleisch als auch Garnelen waren...
# 2002                Waren gestern mit 10 Personen dort.
# 2003  Die gute Laune der Kellner*innen und die Musik...
# 2004                   Netter und freundlicher Service.
# 2005  Wir wurden erst bestimmt eine Stunde komplett ...
# 2006  Als wir dem Kellner dies mitteilten, bot diese...
# 2007  Die Lage, bzw das Restaurant selber entspreche...
# 2008  Nichts tolles, nichts übetkandiedeltes, sonder...
# 2009  Für die Vegetarier gab es immer passend zum ak...
# 2010                                      Ein Alptraum!
# 2011  Wir verstehen, dass die Gastronomie nach LOC P...
# 2012  Die Live Musik ist bemüht, aber die Ansprüche ...
# 2013  LOC mit abwechslungsreichen Speiseangebot, der...
# 2014                Beides schmeckte uns hervorragend !
# 2015  Stattdessen sollte ich einen Sonnenplatz einne...
# 2016  Schönes bairisches Wirtshaus mit katastrophale...
# 2017     Wir waren zum ersten mal in diesem Restaurant.
# 2018  In LOC erwartet Sie ein kulinarischer Ausflug ...
# 2019                         Kommen immer wieder gerne!

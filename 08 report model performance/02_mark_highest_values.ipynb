# %%
import re

def add_bold_font(line_text, idxs):
    values = re.findall(r'\d+\.\d{2}', line_text)
    
    for i, val in enumerate(values):
        if i in idxs:
            line_text = line_text.replace(val, f'\\textbf{{{val}}}', 1)

    return line_text


def mark_highest_value_latex(input_latex):
    lines = input_latex.strip().split('\n')

    first_values = re.findall(r'\d+\.\d{2}', lines[0])

    highest_values = {}

    for i, val in enumerate(first_values):
       highest_values[str(i)] = float(first_values[i])

    # Ermitteln der höchsten scores
    for i, line in enumerate(lines):
        values = re.findall(r'\d+\.\d{2}', line)
        for val_idx, val in enumerate(values):
            if highest_values[str(val_idx)] < float(val):
                highest_values[str(val_idx)] = float(val)
    
    # Ersetzen
    for i, line in enumerate(lines):
        values = re.findall(r'\d+\.\d{2}', line)
        idxs = []
        for val_idx, val in enumerate(values):
            if float(val) == highest_values[str(val_idx)]:
                idxs.append(val_idx)

        lines[i] = add_bold_font(line, idxs)


    return "\n".join(lines)


def load_latex_from_file(file_path):
    with open(file_path, 'r') as file:
        latex_code = file.read()
    return latex_code

latex_string = load_latex_from_file('input.txt')


marked_latex = mark_highest_value_latex(latex_string)
print(marked_latex)
# Out:
# \multirow{3}{*}{\textbf{Real Examples}} & \multirow{3}{*}{-} & 500 & 0 & 43.26\textsubscript{\textbf{26.86}} & 98.93\textsubscript{0.54} & 0.00\textsubscript{0.00} & 99.37\textsubscript{0.21} & 81.58\textsubscript{5.02} & 98.03\textsubscript{0.67} \\
#  &  & 1,000 & 0 & 85.70\textsubscript{8.04} & 99.57\textsubscript{0.31} & 57.30\textsubscript{31.65} & 99.63\textsubscript{0.24} & 85.79\textsubscript{4.59} & 98.40\textsubscript{0.55} \\
#  &  & 2,000 & 0 & \textbf{87.12}\textsubscript{9.44} & \textbf{99.60}\textsubscript{0.33} & \textbf{71.75}\textsubscript{21.87} & \textbf{99.67}\textsubscript{0.25} & \textbf{86.70}\textsubscript{5.19} & \textbf{98.50}\textsubscript{0.60} \\
# \hline
# \multirow{6}{*}{\textbf{Llama-2-70B}} & \multirow{3}{*}{\textbf{LRS\textsubscript{25}}} & 25 & 475 & 62.42\textsubscript{12.23} & 99.13\textsubscript{0.41} & 33.93\textsubscript{\textbf{34.24}} & 99.27\textsubscript{0.41} & 53.97\textsubscript{7.43} & 96.27\textsubscript{0.67} \\
#  &  & 25 & 975 & 66.59\textsubscript{14.08} & 98.97\textsubscript{0.53} & 33.60\textsubscript{19.96} & 99.13\textsubscript{0.22} & 65.99\textsubscript{14.12} & 97.03\textsubscript{\textbf{1.12}} \\
#  &  & 25 & 1,975 & 64.62\textsubscript{9.58} & 98.80\textsubscript{\textbf{0.71}} & 38.84\textsubscript{19.81} & 99.03\textsubscript{0.44} & 65.91\textsubscript{3.97} & 96.80\textsubscript{0.43} \\
# \arrayrulecolor{gray}\cline{2-10}\arrayrulecolor{black}
#  & \multirow{3}{*}{\textbf{LRS\textsubscript{500}}} & 500 & 500 & 73.28\textsubscript{16.92} & 99.23\textsubscript{0.51} & 38.61\textsubscript{23.38} & 99.10\textsubscript{0.40} & 81.24\textsubscript{3.15} & 98.03\textsubscript{0.37} \\
#  &  & 500 & 1,000 & 78.06\textsubscript{19.04} & 99.40\textsubscript{0.42} & 33.69\textsubscript{29.10} & 99.17\textsubscript{0.41} & 77.63\textsubscript{2.58} & 97.70\textsubscript{0.22} \\
#  &  & 500 & 1,500 & 75.25\textsubscript{11.02} & 99.30\textsubscript{0.32} & 46.94\textsubscript{26.92} & 99.27\textsubscript{0.44} & 76.04\textsubscript{5.43} & 97.60\textsubscript{0.42} \\
# \arrayrulecolor{gray}\cline{2-10}\arrayrulecolor{black}
# \hline
# \multirow{6}{*}{\textbf{GPT-3.5-turbo}} & \multirow{3}{*}{\textbf{LRS\textsubscript{25}}} & 25 & 475 & 48.86\textsubscript{18.74} & 98.97\textsubscript{0.48} & 8.33\textsubscript{18.63} & 99.33\textsubscript{0.25} & 49.84\textsubscript{\textbf{17.50}} & 96.33\textsubscript{1.07} \\
#  &  & 25 & 975 & 59.02\textsubscript{14.47} & 98.83\textsubscript{0.42} & 16.67\textsubscript{25.46} & 99.10\textsubscript{0.32} & 68.61\textsubscript{7.40} & 97.13\textsubscript{0.75} \\
#  &  & 25 & 1,975 & 66.04\textsubscript{4.35} & 98.87\textsubscript{0.43} & 33.95\textsubscript{11.22} & 98.73\textsubscript{\textbf{0.52}} & 67.34\textsubscript{7.45} & 96.87\textsubscript{0.81} \\
# \arrayrulecolor{gray}\cline{2-10}\arrayrulecolor{black}
#  & \multirow{3}{*}{\textbf{LRS\textsubscript{500}}} & 500 & 500 & 69.66\textsubscript{7.73} & 99.07\textsubscript{0.43} & 61.94\textsubscript{24.65} & 99.47\textsubscript{0.39} & 80.04\textsubscript{4.70} & 97.93\textsubscript{0.50} \\
#  &  & 500 & 1,000 & 77.42\textsubscript{7.10} & 99.30\textsubscript{0.34} & 63.06\textsubscript{13.89} & 99.53\textsubscript{0.19} & 82.33\textsubscript{5.04} & 98.17\textsubscript{0.58} \\
#  &  & 500 & 1,500 & 71.70\textsubscript{7.38} & 99.10\textsubscript{0.34} & 62.94\textsubscript{9.60} & 99.47\textsubscript{0.19} & 80.67\textsubscript{4.56} & 98.00\textsubscript{0.69} \\
# \arrayrulecolor{gray}\cline{2-10}\arrayrulecolor{black}
# \hline

# %%
import re

def add_bold_font(line_text, idxs):
    values = re.findall(r'(\d+\.\d{2})(\\textsubscript{\d+\.\d{2}})?', line_text)
    
    for i, (value, subscript) in enumerate(values):
        if i in idxs:
            if subscript:
                line_text = line_text.replace(f'{value}{subscript}', f'\\textbf{{{value}}}{subscript}', 1)
            else:
                line_text = line_text.replace(value, f'\\textbf{{{value}}}', 1)

    return line_text

def mark_highest_value_latex(input_latex):
    lines = input_latex.strip().split('\n')

    first_values = re.findall(r'\d+\.\d{2}(?:\\textsubscript{\d+\.\d{2}})?', lines[0])

    highest_values = {}

    for i, val in enumerate(first_values):
        highest_values[str(i)] = float(re.search(r'\d+\.\d{2}', val).group())

    # Ermitteln der höchsten scores
    for i, line in enumerate(lines):
        values = re.findall(r'\d+\.\d{2}(?:\\textsubscript{\d+\.\d{2}})?', line)
        for val_idx, val in enumerate(values):
            score = float(re.search(r'\d+\.\d{2}', val).group())
            if highest_values[str(val_idx)] < score:
                highest_values[str(val_idx)] = score
    
    # Ersetzen
    for i, line in enumerate(lines):
        values = re.findall(r'\d+\.\d{2}(?:\\textsubscript{\d+\.\d{2}})?', line)
        idxs = []
        for val_idx, val in enumerate(values):
            score = float(re.search(r'\d+\.\d{2}', val).group())
            if score == highest_values[str(val_idx)]:
                idxs.append(val_idx)

        lines[i] = add_bold_font(line, idxs)

    return "\n".join(lines)

def load_latex_from_file(file_path):
    with open(file_path, 'r') as file:
        latex_code = file.read()
    return latex_code

# Beispielaufruf
latex_string = load_latex_from_file('input.txt')
marked_latex = mark_highest_value_latex(latex_string)
print(marked_latex)
# Out:
# \multirow{3}{*}{\textbf{Real Examples}} & \multirow{3}{*}{-} & 500 & 0 & 43.26\textsubscript{26.86} & 98.93\textsubscript{0.54} & 0.00\textsubscript{0.00} & 99.37\textsubscript{0.21} & 81.58\textsubscript{5.02} & 98.03\textsubscript{0.67} \\
#  &  & 1,000 & 0 & 85.70\textsubscript{8.04} & 99.57\textsubscript{0.31} & 57.30\textsubscript{31.65} & 99.63\textsubscript{0.24} & 85.79\textsubscript{4.59} & 98.40\textsubscript{0.55} \\
#  &  & 2,000 & 0 & \textbf{87.12}\textsubscript{9.44} & \textbf{99.60}\textsubscript{0.33} & \textbf{71.75}\textsubscript{21.87} & \textbf{99.67}\textsubscript{0.25} & \textbf{86.70}\textsubscript{5.19} & \textbf{98.50}\textsubscript{0.60} \\
# \hline
# \multirow{6}{*}{\textbf{Llama-2-70B}} & \multirow{3}{*}{\textbf{LRS\textsubscript{25}}} & 25 & 475 & 62.42\textsubscript{12.23} & 99.13\textsubscript{0.41} & 33.93\textsubscript{34.24} & 99.27\textsubscript{0.41} & 53.97\textsubscript{7.43} & 96.27\textsubscript{0.67} \\
#  &  & 25 & 975 & 66.59\textsubscript{14.08} & 98.97\textsubscript{0.53} & 33.60\textsubscript{19.96} & 99.13\textsubscript{0.22} & 65.99\textsubscript{14.12} & 97.03\textsubscript{1.12} \\
#  &  & 25 & 1,975 & 64.62\textsubscript{9.58} & 98.80\textsubscript{0.71} & 38.84\textsubscript{19.81} & 99.03\textsubscript{0.44} & 65.91\textsubscript{3.97} & 96.80\textsubscript{0.43} \\
# \arrayrulecolor{gray}\cline{2-10}\arrayrulecolor{black}
#  & \multirow{3}{*}{\textbf{LRS\textsubscript{500}}} & 500 & 500 & 73.28\textsubscript{16.92} & 99.23\textsubscript{0.51} & 38.61\textsubscript{23.38} & 99.10\textsubscript{0.40} & 81.24\textsubscript{3.15} & 98.03\textsubscript{0.37} \\
#  &  & 500 & 1,000 & 78.06\textsubscript{19.04} & 99.40\textsubscript{0.42} & 33.69\textsubscript{29.10} & 99.17\textsubscript{0.41} & 77.63\textsubscript{2.58} & 97.70\textsubscript{0.22} \\
#  &  & 500 & 1,500 & 75.25\textsubscript{11.02} & 99.30\textsubscript{0.32} & 46.94\textsubscript{26.92} & 99.27\textsubscript{0.44} & 76.04\textsubscript{5.43} & 97.60\textsubscript{0.42} \\
# \arrayrulecolor{gray}\cline{2-10}\arrayrulecolor{black}
# \hline
# \multirow{6}{*}{\textbf{GPT-3.5-turbo}} & \multirow{3}{*}{\textbf{LRS\textsubscript{25}}} & 25 & 475 & 48.86\textsubscript{18.74} & 98.97\textsubscript{0.48} & 8.33\textsubscript{18.63} & 99.33\textsubscript{0.25} & 49.84\textsubscript{17.50} & 96.33\textsubscript{1.07} \\
#  &  & 25 & 975 & 59.02\textsubscript{14.47} & 98.83\textsubscript{0.42} & 16.67\textsubscript{25.46} & 99.10\textsubscript{0.32} & 68.61\textsubscript{7.40} & 97.13\textsubscript{0.75} \\
#  &  & 25 & 1,975 & 66.04\textsubscript{4.35} & 98.87\textsubscript{0.43} & 33.95\textsubscript{11.22} & 98.73\textsubscript{0.52} & 67.34\textsubscript{7.45} & 96.87\textsubscript{0.81} \\
# \arrayrulecolor{gray}\cline{2-10}\arrayrulecolor{black}
#  & \multirow{3}{*}{\textbf{LRS\textsubscript{500}}} & 500 & 500 & 69.66\textsubscript{7.73} & 99.07\textsubscript{0.43} & 61.94\textsubscript{24.65} & 99.47\textsubscript{0.39} & 80.04\textsubscript{4.70} & 97.93\textsubscript{0.50} \\
#  &  & 500 & 1,000 & 77.42\textsubscript{7.10} & 99.30\textsubscript{0.34} & 63.06\textsubscript{13.89} & 99.53\textsubscript{0.19} & 82.33\textsubscript{5.04} & 98.17\textsubscript{0.58} \\
#  &  & 500 & 1,500 & 71.70\textsubscript{7.38} & 99.10\textsubscript{0.34} & 62.94\textsubscript{9.60} & 99.47\textsubscript{0.19} & 80.67\textsubscript{4.56} & 98.00\textsubscript{0.69} \\
# \arrayrulecolor{gray}\cline{2-10}\arrayrulecolor{black}
# \hline

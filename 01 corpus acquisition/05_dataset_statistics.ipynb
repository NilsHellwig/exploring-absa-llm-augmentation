# %% [markdown]
# # Notebook: View Dataset Statistics

# %% [markdown]
# This notebook is used to explore a given dataset.

# %% [markdown]
# ## Packages

# %%
import pandas as pd
import tiktoken
import re

# %% [markdown]
# ## Constants

# %%
DATASET_PATH = "reviews_dataset/balanced_reviews_sentences.csv"
LLM_MODEL_NAME = "gpt-3.5-turbo"

# %% [markdown]
# ## Code

# %% [markdown]
# ### General Statistics

# %%
df = pd.read_csv(DATASET_PATH)
df
# Out:
#       Unnamed: 0.1  Unnamed: 0  review_id  restaurant_id  page_index  \
# 0                0        3124  885663660         908561           0
# 1                1         338  909600304         742684           0
# 2                2         988  884767828         965262           0
# 3                3        1552  867801811         718273           0
# 4                4        3396  860042926        2049344           1
# ...            ...         ...        ...            ...         ...
# 3995          3995        3503  855090309        6541566           1
# 3996          3996         360  897549645         947503           0
# 3997          3997         380  866848042         947503           2
# 3998          3998        3354  898452974        2640161           0
# 3999          3999        3483  867349215        7897841           2
#
#                                                   title        date  \
# 0          Schon lange nicht mehr so schlecht gegessen   2023-04-10
# 1                                       Keine Bedienung  2023-08-11
# 2            Ein Besuch in einem Düsseldorfer Brauhaus!  2023-04-04
# 3                         gutes Essen in der Innenstadt  2022-11-09
# 4     Traditionscafé, das auch in Wie sein könnte, e...  2022-09-14
# ...                                                 ...         ...
# 3995                         Leider nicht zu empfehlen   2022-08-19
# 3996  Bei der lausigen Küche hilft die prächtige Dek...  2023-06-24
# 3997                                      Kurzer Imbiss  2022-11-01
# 3998                               ein gelungener Abend  2023-06-27
# 3999                               Immer wieder perfekt  2022-11-05
#
#                author_name           author_location  \
# 0          michaellL5805JV        Lissabon, Portugal
# 1                Patrick F                       NaN
# 2                Andreas K      Leipzig, Deutschland
# 3                  Zwerg74                    Aachen
# 4                   gmsorg  Bad Homburg, Deutschland
# ...                    ...                       ...
# 3995             Michael P     Erkelenz, Deutschland
# 3996  Happiness24765324521         Paris, Frankreich
# 3997            509markuss         Küsnacht, Schweiz
# 3998              garyaugs     Augsburg, Deutschland
# 3999         E1706PUharryh                       NaN
#
#                                                    text  rating  \
# 0     Suppe war nicht heiß, kümmerte den Service abe...     1.0
# 1     Keine BedienungSind 1 1/2 Stunden im Gastgarte...     2.0
# 2     Im Vergleich zum Personal im Schlüssel und LOC...     3.0
# 3                              Wir würden wiederkommen.     4.0
# 4     LOC, eine beeindruckende Kuchen- und Tortenaus...     5.0
# ...                                                 ...     ...
# 3995  Ein weiteres absolutes NoGo war, dass sich wäh...     1.0
# 3996  Sehr schade, da sitzt man im "LOC", einem der ...     2.0
# 3997  Gestresste überhebliche Kellner und das Essen ...     3.0
# 3998  Im Rahmen einer Führung sind wir zu Besuch im ...     4.0
# 3999                            Immer wieder sehr gerne     5.0
#
#                  city                       restaurant_name language_code  \
# 0           karlsruhe               Anders auf dem Turmberg            de
# 1             münchen                           Hofbräuhaus            de
# 2          düsseldorf                   Uerige Hausbrauerei            de
# 3            dortmund                           Pfefferkorn            de
# 4           wiesbaden                         Cafe Maldaner            de
# ...               ...                                   ...           ...
# 3995  mönchengladbach             L'Osteria Mönchengladbach            de
# 3996          münchen                  Augustiner Stammhaus            de
# 3997          münchen                  Augustiner Stammhaus            de
# 3998         augsburg                     Riegele Wirtshaus            de
# 3999  mönchengladbach  Asiatisches Restaurant Kaiser Garten            de
#
#                                    text_noanonymization  sentence_idx  \
# 0     Schon lange nicht mehr so schlecht gegessen! A...             3
# 1     Keine BedienungSind 1 1/2 Stunden im Gastgarte...             0
# 2     Wir sind an einem Sonntagnachmittag durch mehr...             6
# 3     Das Essen war geschmacklich toll und Preis-Lei...             1
# 4     Mitten in Wiesbaden in der belebten Fußgängerz...             1
# ...                                                 ...           ...
# 3995  Leider waren wir sehr unzufrieden und besuchen...             8
# 3996  Sehr schade, da sitzt man im "Arkadengarten", ...             0
# 3997  Wir kannten das Restaurant von früher, aber al...             1
# 3998  Im Rahmen einer Führung sind wir zu Besuch im ...             0
# 3999  Heute Mal wieder ein wunderbares Essen am Sams...             2
#
#                                         id detected_language
# 0     29201856-9893-4eec-a44a-82174cbd867c                de
# 1     5ed24454-faec-4944-b968-b84b9fa5cb6e                de
# 2     294fe7a8-c829-4706-89f7-cf88341c4828                de
# 3     81343575-4711-4a44-bcb1-932dc3c2e0c0                de
# 4     b654d8c6-c609-48d6-9bbb-cac33caeff87                de
# ...                                    ...               ...
# 3995  0764555d-88c3-4816-9177-c6ab11c87f9d                de
# 3996  624cc1d8-2334-4e13-9a6b-c9767c68baf3                de
# 3997  43e534c1-b1f6-4692-a9b6-71b398d431cf                de
# 3998  fd93a399-1e35-466a-a8d7-54c6fd77b6bf                de
# 3999  3d009d26-ea93-43df-b091-671cd38a823d                de
#
# [4000 rows x 18 columns]

# %%
rating_counts = df['rating'].value_counts()
rating_counts
# Out:
# rating
# 1.0    800
# 2.0    800
# 3.0    800
# 4.0    800
# 5.0    800
# Name: count, dtype: int64

# %%
rating_counts = df['city'].value_counts()
rating_counts
# Out:
# city
# hamburg            433
# leipzig            322
# dresden            313
# münchen            265
# düsseldorf         195
# münster            175
# köln               174
# frankfurt          173
# bonn               172
# stuttgart          169
# nürnberg           154
# berlin             144
# augsburg           143
# bremen             129
# mönchengladbach    124
# mannheim           121
# wiesbaden          121
# bochum             120
# bielefeld          114
# hannover           105
# essen              103
# karlsruhe           82
# dortmund            66
# wuppertal           55
# duisburg            28
# Name: count, dtype: int64

# %%
rating_counts = df['restaurant_name'].value_counts()
rating_counts
# Out:
# restaurant_name
# Bullerei                    203
# Mamma Mia                   175
# Ratskeller                  174
# Olive                        96
# Schneider Bräuhaus           93
#                            ...
# Thai Banyan Restaurant        4
# Ola Lisboa                    3
# Argentina - Steak & Mehr      3
# bratar - Erbprinzen 27        2
# Tokyo Sushi Bar               2
# Name: count, Length: 122, dtype: int64

# %%
#df.groupby(['sentence_idx', 'review_id']).size().reset_index(name='count')

# %%
def count_words(text):
    words = re.findall(r'\w+', text)
    return len(words)

df['word_count'] = df['text'].apply(count_words)

# %%
# Standarddeviation
df['word_count'].std()
# Out:
# 11.89603454557347

# %%
# Mean
df['word_count'].mean()
# Out:
# 13.579

# %%
# Median
df['word_count'].median()
# Out:
# 11.0

# %%
# Min, Max
df['word_count'].min(), df['word_count'].max()
# Out:
# (1, 204)

# %%
# Source: https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb
def num_tokens_from_string(string: str, model_name: str) -> int:
    encoding = tiktoken.encoding_for_model(model_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

# %%
df['llm_token_count'] = df['text'].apply(num_tokens_from_string, model_name=LLM_MODEL_NAME)

# %%
df['llm_token_count'].min(), df['llm_token_count'].max()
# Out:
# (2, 344)

# %%
top_10_highest_tokens = df.nlargest(10, 'llm_token_count')
top_10_highest_tokens
# Out:
#       Unnamed: 0.1  Unnamed: 0  review_id  restaurant_id  page_index  \
# 3696          3696        2371  871086663        6931269           0
# 2699          2699         298  893195355         695667           0
# 2055          2055         764  911246241        1341959           0
# 1104          1104        3244  874893103        7322855          11
# 2390          2390        1725  864019871        2049557           1
# 3640          3640        1731  880313943         742761           0
# 3022          3022        2705  883612634        3196403           7
# 1622          1622         279  854552905        2271294           3
# 1582          1582        1093  875273958        1340438           1
# 1228          1228         443  904955470         718846           0
#
#                                                   title        date  \
# 3696                                Bescheidener Beisel  2022-12-08
# 2699  Trompetengalaktisch und sehr geil, am liebsten...  2023-06-03
# 2055                       Sehr unfreundliches Personal  2023-08-18
# 1104                     Erstklassig und unvergleichbar  2023-01-12
# 2390                                 Schwer enttäuscht   2022-10-10
# 3640                 Service sehr nett ….aber das Essen  2023-02-27
# 3022  Spitzenplatz bei Bewertung nicht gerechtfertig...  2023-03-26
# 1622      Leider nicht so zufrieden wie sonst zumeist …  2022-08-16
# 1582                Preis-Leistung leider nicht gegeben  2023-01-16
# 1228                            Nicht nur für Touristen  2023-07-23
#
#              author_name             author_location  \
# 3696             Torston         Bochum, Deutschland
# 2699            rennboot        Hamburg, Deutschland
# 2055  Seaside48854597079                         NaN
# 1104     W1804MDmichaelm                         NaN
# 2390        Y7454NFmikev                         NaN
# 3640          Erkenntnis        Brinkum, Deutschland
# 3022           Michael S                         NaN
# 1622          SanMic2804  Aschaffenburg, Deutschland
# 1582          thomaso893      Böblingen, Deutschland
# 1228     SamuelRappaport        München, Deutschland
#
#                                                    text  rating        city  \
# 3696  Seit Jahren eine gute Adresse , gerade für Gan...     2.0      bochum
# 2699  An der Bar einen kleinen Aperitif und dann geh...     5.0     hamburg
# 2055  Zu diesem Zeitpunkt waren fast alle Tische im ...     1.0   frankfurt
# 1104  Bereits vor unserem Besuch hörten wir öfter vo...     5.0    augsburg
# 2390  Schwer enttäuschtBratkartoffeln aus der fritös...     1.0      bremen
# 3640  Wir waren mit vier Personen dort und alle habe...     1.0      bremen
# 3022  Die 3 bevorzugten griechischen Restaurants in ...     3.0        bonn
# 1622  ich liebe das Hard Rock Café eigentlich sehr- ...     3.0     hamburg
# 1582  Ein wirklich schönes Lokal, der Karte nach etw...     3.0  düsseldorf
# 1228  So probierte ich etwa LOC, LOC oder Saures Lün...     4.0     münchen
#
#                    restaurant_name language_code  \
# 3696               Franz Ferdinand            de
# 2699     Fischereihafen-Restaurant            de
# 2055                       Atschel            de
# 1104               SteakManufaktur            de
# 2390  Schüttinger Gasthausbrauerei            de
# 3640                      El Mundo            de
# 3022                         Olive            de
# 1622                Hard Rock Cafe            de
# 1582                     Fischhaus            de
# 1228            Schneider Bräuhaus            de
#
#                                    text_noanonymization  sentence_idx  \
# 3696  Seit Jahren eine gute Adresse , gerade für Gan...             0
# 2699  Moin Folks,können vier Gäste lügen, ich denke ...             1
# 2055  Diese Apfelweinwirtschaft kann ich leider nich...             1
# 1104  Bereits vor unserem Besuch hörten wir öfter vo...             0
# 2390  Schwer enttäuschtBratkartoffeln aus der fritös...             0
# 3640  Wir waren mit vier Personen dort und alle habe...             0
# 3022  Stand März 2023 (Nr. 2 von 477 Restaurants in ...             2
# 1622  ich liebe das Hard Rock Café eigentlich sehr- ...             0
# 1582  Ein wirklich schönes Lokal, der Karte nach etw...             0
# 1228  Wir besuchen dieses Lokal in unredelmäßigen Ab...             1
#
#                                         id detected_language  word_count  \
# 3696  49df65f6-5b51-4b3a-bf5f-11ddcae08be1                de         204
# 2699  f6268a7c-3f4f-4cfb-b918-9694ec8f7405                de         149
# 2055  b010cba9-3de3-4392-aa23-17ea251a9c56                de         112
# 1104  47c984de-810d-405b-bc93-4787ff157a8d                de         108
# 2390  28824f4e-bc50-4d64-92dc-9e9e43cf1433                de         109
# 3640  36119430-28fa-4a7d-ad84-b21a875872a2                de         116
# 3022  4f4d654e-e729-4a11-b293-82bb3923d8dc                de          87
# 1622  b7175855-424c-44ef-b4ac-fa82d05a820d                de         118
# 1582  381c21f5-b145-4398-8fd2-f47a8b99efba                de          97
# 1228  0d19e177-5621-4a7b-9581-4c31d6d70d3e                de          81
#
#       llm_token_count
# 3696              344
# 2699              244
# 2055              214
# 1104              195
# 2390              195
# 3640              186
# 3022              185
# 1622              173
# 1582              168
# 1228              162

# %% [markdown]
# ### Count Tokens (for LLM)

# %%
df['llm_token_count'] = df['text'].apply(lambda x: num_tokens_from_string(x, LLM_MODEL_NAME))

# %%
pd.set_option('display.max_colwidth', None)

# %%
max_token_row = df[df['llm_token_count'] == df['llm_token_count'].max()]
print("Zeile mit den meisten Tokens:")
max_token_row#["llm_token_count"].values[0]
# Out:
# Zeile mit den meisten Tokens:
#       Unnamed: 0.1  Unnamed: 0  review_id  restaurant_id  page_index  \
# 3696          3696        2371  871086663        6931269           0
#
#                     title        date author_name      author_location  \
# 3696  Bescheidener Beisel  2022-12-08     Torston  Bochum, Deutschland
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               text  \
# 3696  Seit Jahren eine gute Adresse , gerade für Ganz und Co im November Dezember Heute kam die Vorspeise zeitgleich mit dem Aperitif Der laff und uninspiriert daher kam - anschließend ließ der Service dann auf sich warten Die Gänsekeule war zu lang im Konvektomaten oder der Mikrowelle,Die Soße dick und uninspirierte mit teils uninspirierten, gegarten MaronenOb es geschmeckt habe wurde nicht gefragt , warum auch der Laden war ja voll Also fragte ich ob es denn nicht interessiere wie es denn so war, aber ja , natürlich …Die angebrachte Kritik wurde mit ich leite es so weiter beantwortet - erst auf Nachfrage oben es denn nicht abgebracht sei sich mal zu entschuldigen wurde uns beschieden na ja ok aber ich mach ja nur Service Auf dem angestrebten Niveau nicht haltbare, da ist jeder kleine Beisel in LOC besser und ehrlicherNach heute ist das Fazit nüchtern - 105 Euro für das für 2 Personen und diese Behandlung - Nicht nochmals — in LOC scheinen sich halbwegs gute Gastronomiebetriebe immer wieder gern selbstgerecht oder faul und gierig herunterzuwirtschaften manche schneller manche länger und nachhaltiger aber immer mit dem Blick auf den eigenen Geldbeutel Schade schade schade RESTAURANT_NAME - jetzt schick mit FF gebrandet - zu FF fällt mir nach dem heutigen Abend etwas anderes ein
#
#       rating    city  restaurant_name language_code  \
# 3696     2.0  bochum  Franz Ferdinand            de
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   text_noanonymization  \
# 3696  Seit Jahren eine gute Adresse , gerade für Ganz und Co im November Dezember Heute kam die Vorspeise zeitgleich mit dem Aperitif Der laff und uninspiriert daher kam - anschließend ließ der Service dann auf sich warten Die Gänsekeule war zu lang im Konvektomaten oder der Mikrowelle,Die Soße dick und uninspirierte mit teils uninspirierten, gegarten MaronenOb es geschmeckt habe wurde nicht gefragt , warum auch der Laden war ja voll Also fragte ich ob es denn nicht interessiere wie es denn so war, aber ja , natürlich …Die angebrachte Kritik wurde mit ich leite es so weiter beantwortet - erst auf Nachfrage oben es denn nicht abgebracht sei sich mal zu entschuldigen wurde uns beschieden na ja ok aber ich mach ja nur Service Auf dem angestrebten Niveau nicht haltbare, da ist jeder kleine Beisel in Wien besser und ehrlicherNach heute ist das Fazit nüchtern - 105 Euro für das für 2 Personen und diese Behandlung - Nicht nochmals — in Bochum scheinen sich halbwegs gute Gastronomiebetriebe immer wieder gern selbstgerecht oder faul und gierig herunterzuwirtschaften manche schneller manche länger und nachhaltiger aber immer mit dem Blick auf den eigenen Geldbeutel Schade schade schade Franz Ferdinand - jetzt schick mit FF gebrandet - zu FF fällt mir nach dem heutigen Abend etwas anderes ein
#
#       sentence_idx                                    id detected_language  \
# 3696             0  49df65f6-5b51-4b3a-bf5f-11ddcae08be1                de
#
#       word_count  llm_token_count
# 3696         204              344

# %%
with open("../prompt_template.txt", "r", encoding="utf-8") as file:
    prompt_template = file.read()

# %%
template_size = num_tokens_from_string(prompt_template, LLM_MODEL_NAME)
aspect_term_tag_size = num_tokens_from_string('<aspect-term aspect="ambient/interior" polarity="negative"></aspect-term>', LLM_MODEL_NAME)

# %%
template_size + 10 * max_token_row["llm_token_count"].values[0] + aspect_term_tag_size * 20
# Out:
# 4092

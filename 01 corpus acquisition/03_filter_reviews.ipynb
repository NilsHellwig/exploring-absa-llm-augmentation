# %% [markdown]
# # Notebook: Filter Reviews from Collected HTMLs

# %% [markdown]
# ## Packages

# %%
from bs4 import BeautifulSoup
import pandas as pd
import spacy
import json
import nltk
from nltk.tokenize import sent_tokenize
import re

# %% [markdown]
# ## Settings

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/nils_hellwig/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# %%capture
#!python -m spacy download de_core_news_lg

# %%
nlp = spacy.load("de_core_news_lg")

# %% [markdown]
# ## Constants

# %%
RESTAURANT_URLS = "restaurant_metadata_with_highest_page_index.json"
REVIEWS_PATH = "reviews_dataset/reviews_urls.csv"
RANDOM_STATE = 43

# %% [markdown]
# ## Code

# %% [markdown]
# ### Load Dataset

# %%
reviews_df = pd.read_csv(REVIEWS_PATH)

# %% [markdown]
# ### Load Reviews

# %%
columns = ['review_id', 'restaurant_id', 'page_index', 'title', 'date', 'author_name', 'author_location', 'text', 'rating', 'city', 'restaurant_name', 'language_code']
data_reviews = []

# %%
def load_review(review_soup):
    review = {}
    review["title"] = review_soup.find("div", attrs={"class": "quote"}).get_text()
    review["date"] = review_soup.find(class_='ratingDate')['title']
    review["author_name"] = review_soup.find(class_='scrname').get_text()
    user_location_element = review_soup.find(class_='userLocation')
    if user_location_element:
        user_location = user_location_element.get_text()
    else:
        user_location = None
    review["author_location"] = user_location
    review["text"] = review_soup.find(class_='partial_entry').get_text()
    review["rating"] = int(review_soup.find(class_='reviewItemInline').find('span', class_='ui_bubble_rating')['class'][1].split('_')[1]) / 10
    return review

# %%
for index, row in reviews_df.iterrows():
    path_review = "reviews_restaurants_html/restaurant_" + str(row['restaurant_id']) + "_review_" + str(row["review_id"]) + ".html"
    with open(path_review, 'r', encoding='utf-8') as file:
        html_content = file.read()
    doc_soup = BeautifulSoup(html_content, 'html.parser')
    review_soup = doc_soup.find(id="review_"+str(row["review_id"]))
    review = load_review(review_soup)
    try:
        review["language_code"] = doc_soup.find("div", class_="prw_reviews_user_links_hsx").span["data-language"]
    except:
        review["language_code"] = "not defined"
    review["restaurant_name"] = doc_soup.find("a", attrs={"class": "HEADING"}).get_text()[1:-1]
    review["review_id"] = row["review_id"]
    review["restaurant_id"] = row["restaurant_id"]
    review["page_index"] = row["page_index"]
    data_reviews.append(review)

# %%
df_reviews = pd.DataFrame(data_reviews, columns=columns)
df_reviews
# Out:
#       review_id  restaurant_id  page_index  \
# 0     921348897        2005104           0
# 1     921129385        2005104           0
# 2     919660348        2005104           0
# 3     918788541        2005104           0
# 4     917037963        2005104           0
# ...         ...            ...         ...
# 4103  816986993        5207419           1
# 4104  816616877        5207419           1
# 4105  814858898        5207419           1
# 4106  798562672        5207419           1
# 4107  797366586        5207419           1
#
#                                                   title                date  \
# 0                      Bayrisches Bier mitten in Berlin    15. Oktober 2023
# 1                  Denn Sie wissen nicht was Sie tun!!!    13. Oktober 2023
# 2                        Gutes Bier und schöne Aussicht     3. Oktober 2023
# 3     Nicht zu empfehlen! Zero Dienstleistungsverstä...  28. September 2023
# 4     Definitiv nicht authentisch bayerisch, inkompe...  17. September 2023
# ...                                                 ...                 ...
# 4103                                    Tolles Erlebnis    1. November 2021
# 4104                                    Super Schnitzel    30. Oktober 2021
# 4105                      So geht man mit Nörglern um 😍    17. Oktober 2021
# 4106                               Sensationelles Essen       20. Juli 2021
# 4107                                       Reservierung       16. Juli 2021
#
#           author_name                   author_location  \
# 0        wolfganga300                          Erlangen
# 1       Maximilian-62             Freiburg, Deutschland
# 2        PaulSandmann               Berlin, Deutschland
# 3     cariocadagema74               Berlin, Deutschland
# 4              Noah K                              None
# ...               ...                               ...
# 4103       An_Tanja72                              None
# 4104          Frank P      Mönchengladbach, Deutschland
# 4105       sandraz221  Nordrhein-Westfalen, Deutschland
# 4106       Trudchen71                              None
# 4107     annewW4621VQ                              None
#
#                                                    text  rating  city  \
# 0     Bayrisches Bier mitten in Berlin.Das kann man ...     5.0   NaN
# 1     Bayrisch Essen und Gastfreundschaft geht ander...     2.0   NaN
# 2     Am Gendarmenmarkt gelegen, wird hier leckeres ...     4.0   NaN
# 3     Dieser Laden macht den Ruhm Berlins als Servic...     1.0   NaN
# 4     Naja… authentisch bayerisch ist anders. Wir ha...     1.0   NaN
# ...                                                 ...     ...   ...
# 4103  Vielen Dank für die tolle Bewirtung. Das Ambie...     5.0   NaN
# 4104  Wir waren gestern mit 7 Personen da Essen...Wi...     4.0   NaN
# 4105  Ich war tatsächlich noch nie selber vor Ort, h...     5.0   NaN
# 4106  Wir haben noch nie so einen ausgezeichneten Sa...     5.0   NaN
# 4107  Ich bin gerne mit meinem Kegelclub oder mit de...     2.0   NaN
#
#                    restaurant_name language_code
# 0     Augustiner am Gendarmenmarkt            de
# 1     Augustiner am Gendarmenmarkt            de
# 2     Augustiner am Gendarmenmarkt            de
# 3     Augustiner am Gendarmenmarkt            de
# 4     Augustiner am Gendarmenmarkt            de
# ...                            ...           ...
# 4103         Brauerei zum Stefanus            de
# 4104         Brauerei zum Stefanus            de
# 4105         Brauerei zum Stefanus            de
# 4106         Brauerei zum Stefanus            de
# 4107         Brauerei zum Stefanus            de
#
# [4108 rows x 12 columns]

# %% [markdown]
# ### Add city

# %%
with open(RESTAURANT_URLS, 'r') as json_file:
    restaurant_metadata = json.load(json_file)

# %%
restaurant_dict = {entry['id']: entry['city'] for entry in restaurant_metadata}
restaurant_dict_str = {int(k): v for k, v in restaurant_dict.items()}
df_reviews['city'] = df_reviews['restaurant_id'].map(restaurant_dict_str)
df_reviews
# Out:
#       review_id  restaurant_id  page_index  \
# 0     921348897        2005104           0
# 1     921129385        2005104           0
# 2     919660348        2005104           0
# 3     918788541        2005104           0
# 4     917037963        2005104           0
# ...         ...            ...         ...
# 4103  816986993        5207419           1
# 4104  816616877        5207419           1
# 4105  814858898        5207419           1
# 4106  798562672        5207419           1
# 4107  797366586        5207419           1
#
#                                                   title                date  \
# 0                      Bayrisches Bier mitten in Berlin    15. Oktober 2023
# 1                  Denn Sie wissen nicht was Sie tun!!!    13. Oktober 2023
# 2                        Gutes Bier und schöne Aussicht     3. Oktober 2023
# 3     Nicht zu empfehlen! Zero Dienstleistungsverstä...  28. September 2023
# 4     Definitiv nicht authentisch bayerisch, inkompe...  17. September 2023
# ...                                                 ...                 ...
# 4103                                    Tolles Erlebnis    1. November 2021
# 4104                                    Super Schnitzel    30. Oktober 2021
# 4105                      So geht man mit Nörglern um 😍    17. Oktober 2021
# 4106                               Sensationelles Essen       20. Juli 2021
# 4107                                       Reservierung       16. Juli 2021
#
#           author_name                   author_location  \
# 0        wolfganga300                          Erlangen
# 1       Maximilian-62             Freiburg, Deutschland
# 2        PaulSandmann               Berlin, Deutschland
# 3     cariocadagema74               Berlin, Deutschland
# 4              Noah K                              None
# ...               ...                               ...
# 4103       An_Tanja72                              None
# 4104          Frank P      Mönchengladbach, Deutschland
# 4105       sandraz221  Nordrhein-Westfalen, Deutschland
# 4106       Trudchen71                              None
# 4107     annewW4621VQ                              None
#
#                                                    text  rating  \
# 0     Bayrisches Bier mitten in Berlin.Das kann man ...     5.0
# 1     Bayrisch Essen und Gastfreundschaft geht ander...     2.0
# 2     Am Gendarmenmarkt gelegen, wird hier leckeres ...     4.0
# 3     Dieser Laden macht den Ruhm Berlins als Servic...     1.0
# 4     Naja… authentisch bayerisch ist anders. Wir ha...     1.0
# ...                                                 ...     ...
# 4103  Vielen Dank für die tolle Bewirtung. Das Ambie...     5.0
# 4104  Wir waren gestern mit 7 Personen da Essen...Wi...     4.0
# 4105  Ich war tatsächlich noch nie selber vor Ort, h...     5.0
# 4106  Wir haben noch nie so einen ausgezeichneten Sa...     5.0
# 4107  Ich bin gerne mit meinem Kegelclub oder mit de...     2.0
#
#                  city               restaurant_name language_code
# 0              berlin  Augustiner am Gendarmenmarkt            de
# 1              berlin  Augustiner am Gendarmenmarkt            de
# 2              berlin  Augustiner am Gendarmenmarkt            de
# 3              berlin  Augustiner am Gendarmenmarkt            de
# 4              berlin  Augustiner am Gendarmenmarkt            de
# ...               ...                           ...           ...
# 4103  mönchengladbach         Brauerei zum Stefanus            de
# 4104  mönchengladbach         Brauerei zum Stefanus            de
# 4105  mönchengladbach         Brauerei zum Stefanus            de
# 4106  mönchengladbach         Brauerei zum Stefanus            de
# 4107  mönchengladbach         Brauerei zum Stefanus            de
#
# [4108 rows x 12 columns]

# %% [markdown]
# ### Remove line breaks

# %%
df_reviews['text'] = df_reviews['text'].str.replace('\n', ' ')

# %% [markdown]
# ### Check for Duplicates

# %%
duplicate_rows = df_reviews[df_reviews.duplicated(subset=['review_id'], keep=False)]
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [review_id, restaurant_id, page_index, title, date, author_name, author_location, text, rating, city, restaurant_name, language_code]
# Index: []

# %% [markdown]
# ### Delete Examples without Data

# %% [markdown]
# There are rare cases where the text from the rating is not returned with the GET request to the page from the restaurant rating. These will now be excluded.

# %%
df_reviews = df_reviews.drop(df_reviews[(df_reviews['text'] == '') | (df_reviews['title'] == '')].index)

# %% [markdown]
# ### Remove Reviews Posted Before October 2022

# %%
month_mapping = {
    "Januar": 1, "Februar": 2, "März": 3, "April": 4, "Mai": 5, "Juni": 6,
    "Juli": 7, "August": 8, "September": 9, "Oktober": 10, "November": 11, "Dezember": 12
}

def convert_date(date_string):
    day, month_name, year = date_string.split()
    day = day.replace(".", "")
    month = month_mapping[month_name]
    return pd.Timestamp(int(year), month, int(day))

df_reviews["date"] = df_reviews["date"].apply(convert_date)

# %%
df_reviews = df_reviews[df_reviews["date"] >= pd.Timestamp(2022, 10, 15)]
df_reviews = df_reviews[df_reviews["date"] < pd.Timestamp(2023, 10, 16)]

# %%
df_reviews.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Anonymise Restaurant Chains

# %%
df_reviews["text_noanonymization"] = df_reviews["text"]

# %%
def anonymize_entities(text):
    doc = nlp(text)
    for ent in doc.ents:
        if ent.label_ in ["LOC", "PERSON", "DATE"] and ent.label_ != "Essen":
            text = text.replace(ent.text, f"{ent.label_}")
    return text

df_reviews["text"] = df_reviews["text"].apply(anonymize_entities)

# %%
def anonymize_restaurant_name_chain(text):
    restaurant_names = [
        "vapiano",
        "hans im glück",
        "hans ins glück",
        "dean&david",
        "dean und david",
        "dean & david",
        "dean and david",
        "losteria",
        "l osteria",
        "l'osteria",
        "l‘osteria",
        "l´osteria",
        "Llosteria",
        "L’Osteria",
        "la osteria",
        "L`Osteria",
        "L’Hosteria",
        "blockhouse",
        "block house",
        "block hause",
        "blockhaus",
        "blockouse",
        "Block Houses",
        "vapianos",
    ]
    for name in restaurant_names:
        text = re.sub(r'\b' + re.escape(name) + r'\b', "RESTAURANT_NAME", text, flags=re.IGNORECASE)
    return text

df_reviews["text"] = df_reviews["text"].apply(anonymize_restaurant_name_chain)

# %% [markdown]
# ### Anonymise Restaurant Name

# %%
def anonymize_restaurant_name(text, restaurant_name):
    return re.sub(re.escape(restaurant_name), "RESTAURANT_NAME", text, flags=re.IGNORECASE)
df_reviews["text"] = df_reviews.apply(lambda row: anonymize_restaurant_name(row["text"], row["restaurant_name"]), axis=1)

# %% [markdown]
# ### Anonymise Username

# %%
def anonymize_username(text, username):
    return text.replace(username, "PERSON")
df_reviews["text"] = df_reviews.apply(lambda row: anonymize_username(row["text"], row["author_name"]), axis=1)

# %% [markdown]
# ### Filter German Languages by language code
# We are only considering reviews in german language.

# %%
df_reviews = df_reviews.drop(df_reviews[(df_reviews['language_code'] != 'de')].index)

# %% [markdown]
# ### Store as .csv

# %%
df_reviews.to_csv("reviews_dataset/reviews.csv")

# %%
df_reviews
# Out:
#       review_id  restaurant_id  page_index  \
# 0     921348897        2005104           0
# 1     921129385        2005104           0
# 2     919660348        2005104           0
# 3     918788541        2005104           0
# 4     917037963        2005104           0
# ...         ...            ...         ...
# 3207  892814141        5207419           0
# 3208  890899742        5207419           0
# 3209  889964622        5207419           0
# 3210  870345760        5207419           0
# 3211  865168700        5207419           0
#
#                                                   title       date  \
# 0                      Bayrisches Bier mitten in Berlin 2023-10-15
# 1                  Denn Sie wissen nicht was Sie tun!!! 2023-10-13
# 2                        Gutes Bier und schöne Aussicht 2023-10-03
# 3     Nicht zu empfehlen! Zero Dienstleistungsverstä... 2023-09-28
# 4     Definitiv nicht authentisch bayerisch, inkompe... 2023-09-17
# ...                                                 ...        ...
# 3207                            Leckeres Bier, aber...  2023-05-31
# 3208                                        Preiswucher 2023-05-18
# 3209                                   Nicht besonderes 2023-05-11
# 3210            Ungebührender Empfang, sehr gutes Essen 2022-12-01
# 3211                               Ich liebe diese Haxe 2022-10-19
#
#             author_name               author_location  \
# 0          wolfganga300                      Erlangen
# 1         Maximilian-62         Freiburg, Deutschland
# 2          PaulSandmann           Berlin, Deutschland
# 3       cariocadagema74           Berlin, Deutschland
# 4                Noah K                          None
# ...                 ...                           ...
# 3207          Andreas K                          None
# 3208            Bobby C                          None
# 3209  Mobile28959210843  Mönchengladbach, Deutschland
# 3210             Korich          Görlitz, Deutschland
# 3211         BibiH41366                          None
#
#                                                    text  rating  \
# 0     Bayrisches Bier mitten in LOC.Das kann man im ...     5.0
# 1     Bayrisch Essen und Gastfreundschaft geht ander...     2.0
# 2     Am LOC gelegen, wird hier leckeres Bier und zü...     4.0
# 3     Dieser Laden macht den Ruhm LOC als Servicewüs...     1.0
# 4     Naja… authentisch bayerisch ist anders. Wir ha...     1.0
# ...                                                 ...     ...
# 3207  Atmosphäre des Lokals ist gut, Personal reagie...     2.0
# 3208  Waren heute zum Vatertag da.Wollte eigentlich ...     1.0
# 3209  Das Essen ist okay mehr aber auch nicht. Ambie...     3.0
# 3210  Zunächst einmal wurden wir von einem Mann mit ...     4.0
# 3211  Wir sind nicht zum ersten Mal aber auch defini...     5.0
#
#                  city               restaurant_name language_code  \
# 0              berlin  Augustiner am Gendarmenmarkt            de
# 1              berlin  Augustiner am Gendarmenmarkt            de
# 2              berlin  Augustiner am Gendarmenmarkt            de
# 3              berlin  Augustiner am Gendarmenmarkt            de
# 4              berlin  Augustiner am Gendarmenmarkt            de
# ...               ...                           ...           ...
# 3207  mönchengladbach         Brauerei zum Stefanus            de
# 3208  mönchengladbach         Brauerei zum Stefanus            de
# 3209  mönchengladbach         Brauerei zum Stefanus            de
# 3210  mönchengladbach         Brauerei zum Stefanus            de
# 3211  mönchengladbach         Brauerei zum Stefanus            de
#
#                                    text_noanonymization
# 0     Bayrisches Bier mitten in Berlin.Das kann man ...
# 1     Bayrisch Essen und Gastfreundschaft geht ander...
# 2     Am Gendarmenmarkt gelegen, wird hier leckeres ...
# 3     Dieser Laden macht den Ruhm Berlins als Servic...
# 4     Naja… authentisch bayerisch ist anders. Wir ha...
# ...                                                 ...
# 3207  Atmosphäre des Lokals ist gut, Personal reagie...
# 3208  Waren heute zum Vatertag da.Wollte eigentlich ...
# 3209  Das Essen ist okay mehr aber auch nicht. Ambie...
# 3210  Zunächst einmal wurden wir von einem Mann mit ...
# 3211  Wir sind nicht zum ersten Mal aber auch defini...
#
# [3212 rows x 13 columns]

# %% [markdown]
# # Notebook: Split Dataset in folds

# %% [markdown]
# ## Packages

# %%
from helper import divide_equally, get_examples_for_aspects_in_label, get_examples_as_text, xml_to_json, is_valid_xml, check_valid_aspect_xml, count_sentences_in_text
from IPython.display import clear_output
from itertools import cycle, islice
from dotenv import load_dotenv
from llama_cpp import Llama
import numpy as np
import itertools
import warnings
import random
import openai
import json
import uuid
import os
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/nils_hellwig/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Settings

# %%
SPLIT = 0
MODEL_ID = 0

# %% [markdown]
# ## Parameters

# %%
DATASET_PATH = f'../03 dataset split/real/real_{SPLIT}.json'
MAX_TOKENS = 250
CONTEXT_SIZE = 4096
SEED = int(str(43) + str(SPLIT) + str(MODEL_ID))

# %%
# Setup Classes/Polarities for Synthesis
CLASSES  = ["GENERAL-IMPRESSION", "FOOD", "SERVICE", "AMBIENCE", "PRICE"]
POLARITIES = ["POSITIVE", "NEUTRAL", "NEGATIVE"]
COMBINATIONS = [(aspect, polarity) for polarity in POLARITIES for aspect in CLASSES]

# %%
STOP_CRITERIA = ["Label:", "\n"]

# %%
random.seed(SEED)

# %%
MODELS = ["Llama13B", "Llama70B", "Falcon40B", "GPT-3"]
# 175B, 70B und 40B
MODEL_PATHS = {"Llama13B": "llama-2-13b.Q4_0.gguf", "Llama70B": "llama-2-70b.Q4_0.gguf", "Falcon40B": "falcon-40b-Q4_K_S.gguf"}
MODEL_NAME = MODELS[MODEL_ID]

# %% [markdown]
# ## Code

# %% [markdown]
# ### Create Labels for Synthesis

# %%
label_ratio = {"1": int(0.1 * 500), "2": int(0.4 * 500), "3": int(0.5 * 500)}

# %%
label_ratio
# Out:
# {'1': 50, '2': 200, '3': 250}

# %% [markdown]
# ### Calculate how many Aspect-Polarity Pairs should be used

# %%
n_tuples = 0
for key, value in label_ratio.items():
    n_tuples += int(key) * value
n_tuples
# Out:
# 1200

# %% [markdown]
# ### Create List of balanced aspect-polarity tuples

# %%
def get_500_labels():
    aspect_polarity_tuples_list = list(islice(cycle(COMBINATIONS), n_tuples))
    random.shuffle(aspect_polarity_tuples_list)
    print(aspect_polarity_tuples_list)
    tuples_list = []
    idx_start = 0
    for key, value in label_ratio.items():
        tuple_list_n_aspect = aspect_polarity_tuples_list[idx_start: idx_start + value*int(key)]

        k = 0
        for i in range(int(len(tuple_list_n_aspect)/int(key))):
            tuples_list.append(tuple_list_n_aspect[k:k+int(key)])
            k += int(key)
            
        idx_start += int(key) * int(value)
    random.shuffle(tuples_list)
    return tuples_list

labels = get_500_labels() + get_500_labels() + get_500_labels() + get_500_labels()
len(labels)
# Out:
# [('PRICE', 'POSITIVE'), ('PRICE', 'NEGATIVE'), ('PRICE', 'NEGATIVE'), ('SERVICE', 'NEGATIVE'), ('FOOD', 'POSITIVE'), ('PRICE', 'NEGATIVE'), ('FOOD', 'POSITIVE'), ('PRICE', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('SERVICE', 'NEUTRAL'), ('PRICE', 'POSITIVE'), ('AMBIENCE', 'NEUTRAL'), ('FOOD', 'NEGATIVE'), ('PRICE', 'NEUTRAL'), ('SERVICE', 'POSITIVE'), ('FOOD', 'POSITIVE'), ('FOOD', 'NEGATIVE'), ('AMBIENCE', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('SERVICE', 'NEGATIVE'), ('PRICE', 'POSITIVE'), ('AMBIENCE', 'NEGATIVE'), ('PRICE', 'NEGATIVE'), ('SERVICE', 'POSITIVE'), ('FOOD', 'NEGATIVE'), ('AMBIENCE', 'POSITIVE'), ('FOOD', 'NEUTRAL'), ('PRICE', 'NEGATIVE'), ('PRICE', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('FOOD', 'NEGATIVE'), ('FOOD', 'NEUTRAL'), ('PRICE', 'NEUTRAL'), ('PRICE', 'POSITIVE'), ('SERVICE', 'NEUTRAL'), ('PRICE', 'POSITIVE'), ('AMBIENCE', 'NEUTRAL'), ('SERVICE', 'NEUTRAL'), ('AMBIENCE', 'NEUTRAL'), ('SERVICE', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('AMBIENCE', 'POSITIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('AMBIENCE', 'NEUTRAL'), ('FOOD', 'POSITIVE'), ('SERVICE', 'POSITIVE'), ('SERVICE', 'NEGATIVE'), ('FOOD', 'NEGATIVE'), ('FOOD', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('AMBIENCE', 'NEUTRAL'), ('PRICE', 'NEUTRAL'), ('AMBIENCE', 'NEGATIVE'), ('FOOD', 'NEUTRAL'), ('FOOD', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('PRICE', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('FOOD', 'POSITIVE'), ('SERVICE', 'NEGATIVE'), ('AMBIENCE', 'POSITIVE'), ('AMBIENCE', 'POSITIVE'), ('SERVICE', 'NEUTRAL'), ('FOOD', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('FOOD', 'POSITIVE'), ('AMBIENCE', 'NEGATIVE'), ('AMBIENCE', 'POSITIVE'), ('PRICE', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('SERVICE', 'NEUTRAL'), ('PRICE', 'NEUTRAL'), ('FOOD', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('PRICE', 'NEGATIVE'), ('AMBIENCE', 'POSITIVE'), ('SERVICE', 'POSITIVE'), ('AMBIENCE', 'NEGATIVE'), ('AMBIENCE', 'NEGATIVE'), ('FOOD', 'NEGATIVE'), ('PRICE', 'POSITIVE'), ('SERVICE', 'POSITIVE'), ('SERVICE', 'NEGATIVE'), ('PRICE', 'POSITIVE'), ('AMBIENCE', 'POSITIVE'), ('AMBIENCE', 'NEUTRAL'), ('PRICE', 'POSITIVE'), ('FOOD', 'NEUTRAL'), ('SERVICE', 'NEGATIVE'), ('AMBIENCE', 'NEGATIVE'), ('PRICE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('AMBIENCE', 'NEUTRAL'), ('FOOD', 'NEGATIVE'), ('SERVICE', 'POSITIVE'), ('SERVICE', 'POSITIVE'), ('FOOD', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('AMBIENCE', 'NEGATIVE'), ('PRICE', 'NEUTRAL'), ('PRICE', 'NEUTRAL'), ('AMBIENCE', 'NEGATIVE'), ('AMBIENCE', 'POSITIVE'), ('AMBIENCE', 'NEUTRAL'), ('PRICE', 'NEUTRAL'), ('SERVICE', 'POSITIVE'), ('AMBIENCE', 'POSITIVE'), ('SERVICE', 'NEUTRAL'), ('AMBIENCE', 'NEGATIVE'), ('FOOD', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('PRICE', 'NEUTRAL'), ('FOOD', 'NEGATIVE'), ('SERVICE', 'POSITIVE'), ('FOOD', 'NEGATIVE'), ('FOOD', 'NEGATIVE'), ('PRICE', 'NEGATIVE'), ('PRICE', 'NEGATIVE'), ('SERVICE', 'NEGATIVE'), ('AMBIENCE', 'POSITIVE'), ('AMBIENCE', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('AMBIENCE', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('AMBIENCE', 'NEGATIVE'), ('SERVICE', 'NEUTRAL'), ('PRICE', 'POSITIVE'), ('AMBIENCE', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('AMBIENCE', 'NEGATIVE'), ('FOOD', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('PRICE', 'POSITIVE'), ('SERVICE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('SERVICE', 'NEGATIVE'), ('SERVICE', 'NEGATIVE'), ('FOOD', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('FOOD', 'NEUTRAL'), ('AMBIENCE', 'POSITIVE'), ('AMBIENCE', 'NEUTRAL'), ('AMBIENCE', 'POSITIVE'), ('SERVICE', 'NEGATIVE'), ('PRICE', 'NEGATIVE'), ('SERVICE', 'POSITIVE'), (' ...
# [('SERVICE', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('SERVICE', 'POSITIVE'), ('SERVICE', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('FOOD', 'NEUTRAL'), ('AMBIENCE', 'NEUTRAL'), ('SERVICE', 'POSITIVE'), ('AMBIENCE', 'NEGATIVE'), ('FOOD', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('PRICE', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('PRICE', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('AMBIENCE', 'POSITIVE'), ('SERVICE', 'NEUTRAL'), ('AMBIENCE', 'NEGATIVE'), ('SERVICE', 'NEGATIVE'), ('PRICE', 'NEUTRAL'), ('SERVICE', 'NEGATIVE'), ('PRICE', 'NEGATIVE'), ('AMBIENCE', 'POSITIVE'), ('SERVICE', 'NEUTRAL'), ('FOOD', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('PRICE', 'NEGATIVE'), ('SERVICE', 'POSITIVE'), ('PRICE', 'POSITIVE'), ('AMBIENCE', 'NEGATIVE'), ('AMBIENCE', 'POSITIVE'), ('SERVICE', 'POSITIVE'), ('PRICE', 'NEGATIVE'), ('PRICE', 'POSITIVE'), ('FOOD', 'NEUTRAL'), ('FOOD', 'POSITIVE'), ('PRICE', 'POSITIVE'), ('SERVICE', 'NEUTRAL'), ('FOOD', 'NEUTRAL'), ('AMBIENCE', 'POSITIVE'), ('FOOD', 'NEUTRAL'), ('FOOD', 'POSITIVE'), ('FOOD', 'NEUTRAL'), ('SERVICE', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('SERVICE', 'POSITIVE'), ('AMBIENCE', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('AMBIENCE', 'POSITIVE'), ('SERVICE', 'NEUTRAL'), ('PRICE', 'NEGATIVE'), ('AMBIENCE', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('FOOD', 'NEUTRAL'), ('AMBIENCE', 'NEGATIVE'), ('SERVICE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('SERVICE', 'POSITIVE'), ('AMBIENCE', 'NEUTRAL'), ('FOOD', 'NEGATIVE'), ('SERVICE', 'POSITIVE'), ('AMBIENCE', 'POSITIVE'), ('FOOD', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('AMBIENCE', 'POSITIVE'), ('FOOD', 'NEUTRAL'), ('PRICE', 'NEGATIVE'), ('SERVICE', 'NEUTRAL'), ('FOOD', 'NEUTRAL'), ('PRICE', 'NEGATIVE'), ('FOOD', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('FOOD', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('FOOD', 'POSITIVE'), ('FOOD', 'NEUTRAL'), ('FOOD', 'POSITIVE'), ('FOOD', 'NEGATIVE'), ('PRICE', 'NEGATIVE'), ('AMBIENCE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('PRICE', 'POSITIVE'), ('FOOD', 'NEUTRAL'), ('FOOD', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('AMBIENCE', 'POSITIVE'), ('SERVICE', 'POSITIVE'), ('FOOD', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('PRICE', 'NEUTRAL'), ('AMBIENCE', 'NEUTRAL'), ('PRICE', 'POSITIVE'), ('AMBIENCE', 'NEUTRAL'), ('PRICE', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('PRICE', 'NEGATIVE'), ('PRICE', 'NEUTRAL'), ('FOOD', 'POSITIVE'), ('SERVICE', 'NEGATIVE'), ('AMBIENCE', 'POSITIVE'), ('PRICE', 'NEUTRAL'), ('PRICE', 'POSITIVE'), ('PRICE', 'NEUTRAL'), ('SERVICE', 'POSITIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('FOOD', 'POSITIVE'), ('PRICE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('PRICE', 'NEGATIVE'), ('AMBIENCE', 'NEUTRAL'), ('FOOD', 'POSITIVE'), ('AMBIENCE', 'NEGATIVE'), ('SERVICE', 'NEGATIVE'), ('FOOD', 'NEUTRAL'), ('AMBIENCE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('AMBIENCE', 'NEGATIVE'), ('FOOD', 'POSITIVE'), ('SERVICE', 'POSITIVE'), ('AMBIENCE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('FOOD', 'NEGATIVE'), ('FOOD', 'NEGATIVE'), ('FOOD', 'NEGATIVE'), ('SERVICE', 'NEGATIVE'), ('PRICE', 'NEGATIVE'), ('PRICE', 'NEGATIVE'), ('AMBIENCE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('SERVICE', 'NEUTRAL'), ('AMBIENCE', 'NEGATIVE'), ('SERVICE', 'POSITIVE'), ('AMBIENCE', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('FOOD', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('SERVICE', 'NEGATIVE'), ('SERVICE', 'NEGATIVE'), ('SERVICE', 'NEUTRAL'), ('AMBIENCE', 'NEGATIVE'), ('AMBIENCE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('FOOD', 'NEUTRA ...
# [('FOOD', 'NEGATIVE'), ('PRICE', 'POSITIVE'), ('SERVICE', 'NEGATIVE'), ('FOOD', 'NEGATIVE'), ('FOOD', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('SERVICE', 'NEUTRAL'), ('AMBIENCE', 'POSITIVE'), ('FOOD', 'POSITIVE'), ('AMBIENCE', 'NEUTRAL'), ('PRICE', 'NEGATIVE'), ('SERVICE', 'POSITIVE'), ('SERVICE', 'POSITIVE'), ('AMBIENCE', 'POSITIVE'), ('PRICE', 'NEGATIVE'), ('AMBIENCE', 'NEUTRAL'), ('SERVICE', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('AMBIENCE', 'NEUTRAL'), ('PRICE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('PRICE', 'NEUTRAL'), ('AMBIENCE', 'NEUTRAL'), ('FOOD', 'POSITIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('PRICE', 'NEGATIVE'), ('SERVICE', 'NEUTRAL'), ('FOOD', 'NEGATIVE'), ('PRICE', 'NEGATIVE'), ('SERVICE', 'POSITIVE'), ('FOOD', 'NEGATIVE'), ('SERVICE', 'NEUTRAL'), ('AMBIENCE', 'NEGATIVE'), ('SERVICE', 'POSITIVE'), ('PRICE', 'NEGATIVE'), ('AMBIENCE', 'POSITIVE'), ('SERVICE', 'POSITIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('FOOD', 'NEUTRAL'), ('FOOD', 'NEGATIVE'), ('AMBIENCE', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('SERVICE', 'POSITIVE'), ('AMBIENCE', 'NEGATIVE'), ('PRICE', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('AMBIENCE', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('AMBIENCE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('PRICE', 'NEUTRAL'), ('FOOD', 'NEGATIVE'), ('SERVICE', 'POSITIVE'), ('FOOD', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('PRICE', 'NEUTRAL'), ('PRICE', 'NEGATIVE'), ('SERVICE', 'NEGATIVE'), ('AMBIENCE', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('AMBIENCE', 'NEUTRAL'), ('SERVICE', 'POSITIVE'), ('FOOD', 'NEUTRAL'), ('SERVICE', 'NEGATIVE'), ('PRICE', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('SERVICE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('AMBIENCE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('SERVICE', 'NEGATIVE'), ('PRICE', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('AMBIENCE', 'NEUTRAL'), ('SERVICE', 'POSITIVE'), ('SERVICE', 'POSITIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('SERVICE', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('AMBIENCE', 'NEGATIVE'), ('AMBIENCE', 'NEUTRAL'), ('FOOD', 'NEGATIVE'), ('AMBIENCE', 'NEGATIVE'), ('PRICE', 'POSITIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('PRICE', 'POSITIVE'), ('PRICE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('FOOD', 'NEGATIVE'), ('PRICE', 'NEGATIVE'), ('PRICE', 'NEGATIVE'), ('PRICE', 'POSITIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('SERVICE', 'NEUTRAL'), ('PRICE', 'NEUTRAL'), ('PRICE', 'POSITIVE'), ('AMBIENCE', 'POSITIVE'), ('PRICE', 'POSITIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('SERVICE', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('SERVICE', 'POSITIVE'), ('PRICE', 'NEUTRAL'), ('PRICE', 'NEGATIVE'), ('FOOD', 'POSITIVE'), ('FOOD', 'NEUTRAL'), ('SERVICE', 'NEGATIVE'), ('FOOD', 'POSITIVE'), ('PRICE', 'POSITIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('FOOD', 'POSITIVE'), ('PRICE', 'NEGATIVE'), ('SERVICE', 'NEUTRAL'), ('FOOD', 'POSITIVE'), ('AMBIENCE', 'NEGATIVE'), ('PRICE', 'NEGATIVE'), ('FOOD', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('SERVICE', 'NEGATIVE'), ('SERVICE', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('PRICE', 'NEUTRAL'), ('PRICE', 'NEGATIVE'), ('SERVICE', 'NEUTRAL'), ('AMBIENCE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('SERVICE', 'NEUTRAL'), ('SERVICE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('FOOD', 'NEUTRAL'), ('FOOD', 'NEUTRAL'), ('AMBIENCE', 'NEGATIVE'), ('SERVICE', 'POSITIVE'), ('FOOD', 'NEGATIVE'), ('SERVICE', 'NEGATIVE'), ('PRICE', 'POSITIVE'), ('PRICE', 'NEUTRAL'), ('PRICE', 'POSITIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('SERVICE', 'POSITIVE'), ('AMBIENCE', 'POSITIVE'), ('AMBIENCE', 'NEUTRAL'), ('PRICE', 'POSITIVE'), ('SERVICE', 'POSITIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('FOOD', 'NEUTRAL'), ('FOOD', 'N ...
# [('FOOD', 'NEGATIVE'), ('SERVICE', 'NEUTRAL'), ('AMBIENCE', 'NEGATIVE'), ('FOOD', 'NEGATIVE'), ('FOOD', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('FOOD', 'NEUTRAL'), ('FOOD', 'NEGATIVE'), ('PRICE', 'NEUTRAL'), ('FOOD', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('SERVICE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('SERVICE', 'NEGATIVE'), ('FOOD', 'NEGATIVE'), ('FOOD', 'NEUTRAL'), ('PRICE', 'NEUTRAL'), ('FOOD', 'NEUTRAL'), ('AMBIENCE', 'NEGATIVE'), ('SERVICE', 'NEUTRAL'), ('PRICE', 'NEUTRAL'), ('PRICE', 'POSITIVE'), ('SERVICE', 'NEGATIVE'), ('FOOD', 'NEUTRAL'), ('PRICE', 'NEGATIVE'), ('SERVICE', 'NEGATIVE'), ('AMBIENCE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('FOOD', 'POSITIVE'), ('FOOD', 'NEGATIVE'), ('AMBIENCE', 'NEGATIVE'), ('FOOD', 'NEUTRAL'), ('FOOD', 'NEGATIVE'), ('AMBIENCE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('AMBIENCE', 'POSITIVE'), ('SERVICE', 'NEUTRAL'), ('PRICE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('AMBIENCE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('PRICE', 'NEUTRAL'), ('PRICE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('SERVICE', 'NEGATIVE'), ('AMBIENCE', 'NEUTRAL'), ('SERVICE', 'NEUTRAL'), ('SERVICE', 'POSITIVE'), ('PRICE', 'POSITIVE'), ('PRICE', 'POSITIVE'), ('AMBIENCE', 'POSITIVE'), ('SERVICE', 'NEGATIVE'), ('SERVICE', 'NEUTRAL'), ('PRICE', 'POSITIVE'), ('SERVICE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('AMBIENCE', 'POSITIVE'), ('FOOD', 'POSITIVE'), ('AMBIENCE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('PRICE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('FOOD', 'NEGATIVE'), ('SERVICE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('PRICE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('SERVICE', 'NEGATIVE'), ('PRICE', 'POSITIVE'), ('FOOD', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('AMBIENCE', 'NEGATIVE'), ('FOOD', 'POSITIVE'), ('SERVICE', 'NEUTRAL'), ('FOOD', 'NEGATIVE'), ('FOOD', 'POSITIVE'), ('AMBIENCE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('AMBIENCE', 'NEGATIVE'), ('SERVICE', 'NEUTRAL'), ('PRICE', 'NEGATIVE'), ('SERVICE', 'NEUTRAL'), ('SERVICE', 'NEGATIVE'), ('SERVICE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('AMBIENCE', 'POSITIVE'), ('AMBIENCE', 'NEGATIVE'), ('AMBIENCE', 'NEGATIVE'), ('PRICE', 'NEUTRAL'), ('PRICE', 'NEGATIVE'), ('AMBIENCE', 'NEGATIVE'), ('FOOD', 'NEGATIVE'), ('SERVICE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('FOOD', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('SERVICE', 'NEUTRAL'), ('SERVICE', 'NEGATIVE'), ('AMBIENCE', 'POSITIVE'), ('PRICE', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('PRICE', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('PRICE', 'NEGATIVE'), ('AMBIENCE', 'NEUTRAL'), ('PRICE', 'NEUTRAL'), ('PRICE', 'POSITIVE'), ('AMBIENCE', 'NEUTRAL'), ('SERVICE', 'NEUTRAL'), ('SERVICE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('FOOD', 'NEUTRAL'), ('FOOD', 'NEUTRAL'), ('AMBIENCE', 'NEGATIVE'), ('FOOD', 'NEUTRAL'), ('PRICE', 'POSITIVE'), ('PRICE', 'NEUTRAL'), ('SERVICE', 'POSITIVE'), ('SERVICE', 'NEUTRAL'), ('SERVICE', 'POSITIVE'), ('PRICE', 'NEUTRAL'), ('PRICE', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('SERVICE', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('SERVICE', 'NEUTRAL'), ('AMBIENCE', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('PRICE', 'POSITIVE'), ('GENERAL-IMPRESSION', 'POSITIVE'), ('PRICE', 'NEGATIVE'), ('AMBIENCE', 'POSITIVE'), ('FOOD', 'NEGATIVE'), ('PRICE', 'NEUTRAL'), ('SERVICE', 'NEUTRAL'), ('GENERAL-IMPRESSION', 'NEGATIVE'), ('AMBIENCE', 'NEUTRAL'), ('SERVICE', 'NEGATIVE'), ('PRICE', 'NEGATIVE'), ('GENERAL-IMPRESSION', 'NEUTRAL'), ('SERVICE', 'POSITIVE'), ('GENERAL-IMPRESSION', 'NEGATI ...
# 2000

# %% [markdown]
# ### Setup Prompt Template

# %%
with open('../prompt_template.txt', 'r') as file:
    PROMPT_TEMPLATE = file.read()

# %% [markdown]
# ### Load Split

# %%
with open(DATASET_PATH, 'r', encoding='utf-8') as json_file:
    dataset = json.load(json_file)

# %% [markdown]
# ### Setup Model

# %%
if MODEL_NAME == "Llama70B":
    llm = Llama(model_path=MODEL_PATHS[MODEL_NAME], seed=SEED, n_gpu_layers=1, n_ctx=CONTEXT_SIZE, verbose=False, n_gqa=8)
    clear_output(wait=False)
    def llm_model(text):
        return llm(prompt, max_tokens=MAX_TOKENS, stop=STOP_CRITERIA, echo=True, top_p=1)["choices"][0]["text"][len(text):]
    
if MODEL_NAME == "Llama13B" or MODEL_NAME == "Falcon40B":
    llm = Llama(model_path=MODEL_PATHS[MODEL_NAME], seed=SEED, n_gpu_layers=1, n_ctx=CONTEXT_SIZE, verbose=False)
    clear_output(wait=False)
    def llm_model(text):
        return llm(prompt, max_tokens=MAX_TOKENS, stop=STOP_CRITERIA, echo=True, top_p=1)["choices"][0]["text"][len(text):]

# %%
if MODEL_NAME == "GPT-3":
    openai.api_key = os.getenv("OPENAI_API_KEY")
    def llm_model(text):
        response = openai.ChatCompletion.create(
           model="gpt-3.5-turbo",
           messages=[
              {"role": "user", "content": text}
           ],
           max_tokens=MAX_TOKENS,  
           temperature=0.7, 
           stop=STOP_CRITERIA
        )
        return response.choices[0].message.content.strip()

# %% [markdown]
# ### Create Synthetic Samples

# %%
synth_dataset = []

# %%
for label in labels[:5]:
    
    valid_example = False
    invalid_xml_schema = 0
    invalid_xml_tags = 0
    aspect_polarity_in_text_but_not_in_label = 0
    more_than_one_sentences = 0
    
    while valid_example == False:
        unique_aspects = [aspect for aspect, _ in label if label.count((aspect, _)) == 1]
    
        ids_examples_for_aspects = get_examples_for_aspects_in_label(unique_aspects, dataset, random)
        additional_examples = [entry for entry in dataset if entry['id'] not in ids_examples_for_aspects]
        additional_examples = random.sample(additional_examples, 10-len(ids_examples_for_aspects))

        examples = additional_examples + [entry for entry in dataset if entry['id'] in ids_examples_for_aspects]
        examples_text = get_examples_as_text(examples)
    
        prompt_footer = f'\nLabel:{str(label)}\nPrediction:'
        prompt = PROMPT_TEMPLATE + examples_text + prompt_footer
    
        prediction = llm_model(prompt)
        print(prediction)
        
        if is_valid_xml(f'<input>{prediction}</input>') == False:
            invalid_xml_schema += 1
        else:
            if check_valid_aspect_xml(f'<input>{prediction}</input>') == False:
                invalid_xml_tags += 1
            else: 
                prediction_as_json = xml_to_json(prediction, label, MODEL_NAME, SPLIT)
                if prediction_as_json == "not-in-label":
                    aspect_polarity_in_text_but_not_in_label += 1
                else: 
                    if count_sentences_in_text(prediction_as_json["text"]) > 1:
                        more_than_one_sentences += 1
                    else:
                        valid_example = True
    
    prediction_as_json["llm_label"] = label
    prediction_as_json["llm_examples"] = examples
    prediction_as_json["llm_invalid_xml_schema"] = invalid_xml_schema
    prediction_as_json["llm_invalid_xml_tags"] = invalid_xml_tags
    prediction_as_json["llm_aspect_polarity_in_text_but_not_in_label"] = aspect_polarity_in_text_but_not_in_label
    prediction_as_json["llm_more_than_one_sentences"] = more_than_one_sentences
    
    synth_dataset.append(prediction_as_json)
# Out:
# Die <aspect-term aspect="FOOD" polarity="NEUTRAL">Kuchenauswahl</aspect-term> an sich ist sehr umfangreich, wobei sich jedoch einige Klassiker fehlen. Das <aspect-term aspect="AMBIENCE" polarity="NEUTRAL">Coffee House Design</aspect-term> passt auch in die Zeit und die Atmosphäre ist entspannt.
# Mitten im <aspect-term aspect="FOOD" polarity="NEUTRAL">Chalets</aspect-term> und <aspect-term aspect="AMBIENCE" polarity="NEUTRAL">Hütten</aspect-term> der Berge
# Die <aspect-term aspect="SERVICE" polarity="NEUTRAL">Bedienung</aspect-term> war sehr nett, die <aspect-term aspect="PRICE" polarity="NEUTRAL">Preise</aspect-term> waren ok. Die <aspect-term aspect="SERVICE" polarity="NEUTRAL">Kellnerin</aspect-term>, <aspect-term aspect="SERVICE" polarity="NEUTRAL">Kellner</aspect-term> und <aspect-term aspect="SERVICE" polarity="NEUTRAL">Sommelière</aspect-term> waren alle super nett.
# Sehr schön und nicht teuer. Haben einen sehr guten Preis/Leistungsverhältnis erlebt.
# <aspect-term aspect="PRICE" polarity="NEUTRAL">Gastgeschenke</aspect-term> sind ein <aspect-term aspect="SERVICE" polarity="NEUTRAL">Service</aspect-term> (obwohl es natürlich nichts an sich kosten sollte)
# Ach was ist das eigentlich mit dem Preis? Und die Leute sind so nett wie eine Klappe und dann wird <aspect-term aspect="GENERAL-IMPRESSION" polarity="NEGATIVE">alles</aspect-term> für den Preisschnitt geboten.
# Alles <aspect-term aspect="GENERAL-IMPRESSION" polarity="NEGATIVE">war mies</aspect-term>
# Das <aspect-term aspect="FOOD" polarity="NEUTRAL">Essen</aspect-term> war ok, für uns aber zu teuer. Es gibt dafür bessere Optionen in der Nähe.Die Bedienung wäre auch zu verbessern.
# Noch immer <aspect-term aspect="FOOD" polarity="NEUTRAL">Käsespätzle</aspect-term>.
# <aspect-term aspect="PRICE" polarity="POSITIVE">Porzellansuppe</aspect-term> ist einfach zu teuer. <br><br><aspect-term aspect="FOOD" neutrality="NEUTRAL">Käsespätzle</aspect-term>.
# Irgendwann kam unser <aspect-term aspect="SERVICE" polarity="NEGATIVE">Kellner</aspect-term> nicht mehr, wir mussten andere Kellner ansprechen, damit sie ihn holten, um noch <aspect-term aspect="FOOD" polarity="NEUTRAL">Getränke</aspect-term> bestellen zu können.

# %%
json_file_path = f"synth/{MODEL_NAME}/split_{SPLIT}.json"
os.makedirs(os.path.dirname(json_file_path), exist_ok=True)

# %%
with open(json_file_path, "w") as outfile:
    json.dump(synth_dataset, outfile)

# %%
[(example["text"], example["llm_label"], [text["text"] for text in example["llm_examples"]]) for example in synth_dataset]
# Out:
# [('Mitten im Chalets und Hütten der Berge',
#   [('FOOD', 'NEUTRAL'), ('AMBIENCE', 'NEUTRAL')],
#   ['Käsespätzle sind halt nicht mit einer Alm zu vergleichen.',
#    'Käsespätzle sind halt nicht mit einer Alm zu vergleichen.',
#    'LOC, eine beeindruckende Kuchen- und Tortenauswahl und ein Interior Design, das als Filmkulisse für eine Geschischte dienen könnte, die in den goldenen 1920er Jahren spielt.',
#    'Suppe war nicht heiß, kümmerte den Service aber nicht.',
#    'War zwar viel los, dennoch hat das Personal nicht an Höflichkeit und Spaß verloren.',
#    'Niemand hatte den Tisch im Blick, keiner fühlte sich zuständig.',
#    'Irgendwann kam unser Kellner nicht mehr, wir mussten andere Kellner ansprechen, damit sie ihn holten, um noch Getränke bestellen zu können.',
#    'Käsespätzle sind halt nicht mit einer Alm zu vergleichen.',
#    'LOC, eine beeindruckende Kuchen- und Tortenauswahl und ein Interior Design, das als Filmkulisse für eine Geschischte dienen könnte, die in den goldenen 1920er Jahren spielt.',
#    'Käsespätzle sind halt nicht mit einer Alm zu vergleichen.']),
#  ('Gastgeschenke sind ein Service (obwohl es natürlich nichts an sich kosten sollte) ',
#   [('SERVICE', 'NEUTRAL'), ('SERVICE', 'NEUTRAL'), ('PRICE', 'NEUTRAL')],
#   ['Waren 2x dort, da uns das Ambiente eigentlich gut gefällt.',
#    'Keine BedienungSind 1 1/2 Stunden im Gastgarten gesessen aber es hat sich kein Kellner zuständig gefühlt Auch bei Nachfrage ging alles nur sehr schleppendBekamen dan nur ein Getränk und wollten eigentlich essen.',
#    'Unbedingt fernbleiben!',
#    'Suppe war nicht heiß, kümmerte den Service aber nicht.',
#    'Wir sind maximal enttäuscht und werden uns überlegen, ob wir wirklich nochmal hingehen.',
#    'Irgendwann kam unser Kellner nicht mehr, wir mussten andere Kellner ansprechen, damit sie ihn holten, um noch Getränke bestellen zu können.',
#    'War zwar viel los, dennoch hat das Personal nicht an Höflichkeit und Spaß verloren.',
#    'Irgendwann kam unser Kellner nicht mehr, wir mussten andere Kellner ansprechen, damit sie ihn holten, um noch Getränke bestellen zu können.',
#    'Unbedingt fernbleiben!',
#    'Für mich war das leider rausgeworfenes Geld.']),
#  ('Alles war mies',
#   [('GENERAL-IMPRESSION', 'NEGATIVE'), ('PRICE', 'NEUTRAL')],
#   ['Suppe war nicht heiß, kümmerte den Service aber nicht.',
#    'Waren 2x dort, da uns das Ambiente eigentlich gut gefällt.',
#    'Niemand hatte den Tisch im Blick, keiner fühlte sich zuständig.',
#    'Alles war wunderbar.',
#    'Keine BedienungSind 1 1/2 Stunden im Gastgarten gesessen aber es hat sich kein Kellner zuständig gefühlt Auch bei Nachfrage ging alles nur sehr schleppendBekamen dan nur ein Getränk und wollten eigentlich essen.',
#    'Suppe war nicht heiß, kümmerte den Service aber nicht.',
#    'Unbedingt fernbleiben!',
#    'Das Essen war super.',
#    'Für mich war das leider rausgeworfenes Geld.',
#    'Alles war wunderbar.']),
#  ('Noch immer Käsespätzle.',
#   [('FOOD', 'NEUTRAL'), ('SERVICE', 'NEUTRAL'), ('FOOD', 'NEUTRAL')],
#   ['Wir würden wiederkommen.',
#    'Waren 2x dort, da uns das Ambiente eigentlich gut gefällt.',
#    'Wir sind maximal enttäuscht und werden uns überlegen, ob wir wirklich nochmal hingehen.',
#    'Keine BedienungSind 1 1/2 Stunden im Gastgarten gesessen aber es hat sich kein Kellner zuständig gefühlt Auch bei Nachfrage ging alles nur sehr schleppendBekamen dan nur ein Getränk und wollten eigentlich essen.',
#    'Irgendwann kam unser Kellner nicht mehr, wir mussten andere Kellner ansprechen, damit sie ihn holten, um noch Getränke bestellen zu können.',
#    'War zwar viel los, dennoch hat das Personal nicht an Höflichkeit und Spaß verloren.',
#    'Käsespätzle sind halt nicht mit einer Alm zu vergleichen.',
#    'Niemand hatte den Tisch im Blick, keiner fühlte sich zuständig.',
#    'Niemand hatte den Tisch im Blick, keiner fühlte sich zuständig.',
#    'Im Vergleich zum Personal im Schlüssel und LOC bleibt das Uerige aber doch zurück.']),
#  ('Irgendwann kam unser Kellner nicht mehr, wir mussten andere Kellner ansprechen, damit sie ihn holten, um noch Getränke bestellen zu können.',
#   [('SERVICE', 'NEGATIVE'), ('FOOD', 'NEUTRAL'), ('PRICE', 'POSITIVE')],
#   ['Waren 2x dort, da uns das Ambiente eigentlich gut gefällt.',
#    'LOC, eine beeindruckende Kuchen- und Tortenauswahl und ein Interior Design, das als Filmkulisse für eine Geschischte dienen könnte, die in den goldenen 1920er Jahren spielt.',
#    'Unbedingt fernbleiben!',
#    'Alles war wunderbar.',
#    'Waren 2x dort, da uns das Ambiente eigentlich gut gefällt.',
#    'Alles war wunderbar.',
#    'LOC, eine beeindruckende Kuchen- und Tortenauswahl und ein Interior Design, das als Filmkulisse für eine Geschischte dienen könnte, die in den goldenen 1920er Jahren spielt.',
#    'Suppe war nicht heiß, kümmerte den Service aber nicht.',
#    'Irgendwann kam unser Kellner nicht mehr, wir mussten andere Kellner ansprechen, damit sie ihn holten, um noch Getränke bestellen zu können.',
#    'Für mich war das leider rausgeworfenes Geld.'])]

# %% [markdown]
# # Notebook: Create Confirmation Subsets

# %% [markdown]
# ## Packages

# %%
import pandas as pd
import json
import os

# %% [markdown]
# ## Settings

# %%
N_PARTS = 1

# %%
OUTPUT_PATH_PREFIX = "annotation_datasets/annotation_jakob"

# %% [markdown]
# ## Code

# %%
input_folder = 'annotation_datasets/synth_annotation_nils_labelstudio_output'

all_files = [file for file in os.listdir(input_folder) if file.endswith('.csv')]
df = pd.concat([pd.read_csv(os.path.join(input_folder, file)) for file in all_files], ignore_index=True)

# %%
df
# Out:
#       agreement  annotation_id  \
# 0         100.0       29386319
# 1         100.0       29386342
# 2         100.0       29386363
# 3         100.0       29386372
# 4         100.0       29386385
# ...         ...            ...
# 2875      100.0       30094958
# 2876      100.0       30094986
# 2877      100.0       30095001
# 2878      100.0       30095014
# 2879      100.0       30095050
#
#                                            annotator  \
# 0     nils-constantin.hellwig@stud.uni-regensburg.de
# 1     nils-constantin.hellwig@stud.uni-regensburg.de
# 2     nils-constantin.hellwig@stud.uni-regensburg.de
# 3     nils-constantin.hellwig@stud.uni-regensburg.de
# 4     nils-constantin.hellwig@stud.uni-regensburg.de
# ...                                              ...
# 2875  nils-constantin.hellwig@stud.uni-regensburg.de
# 2876  nils-constantin.hellwig@stud.uni-regensburg.de
# 2877  nils-constantin.hellwig@stud.uni-regensburg.de
# 2878  nils-constantin.hellwig@stud.uni-regensburg.de
# 2879  nils-constantin.hellwig@stud.uni-regensburg.de
#
#      aspect_available_without_judgement                   created_at  \
# 0                                   NaN  2024-01-17T12:39:00.806330Z
# 1                                   NaN  2024-01-17T12:39:20.055071Z
# 2                                   NaN  2024-01-17T12:39:39.528689Z
# 3                                   NaN  2024-01-17T12:39:50.874016Z
# 4                                   NaN  2024-01-17T12:40:02.602344Z
# ...                                 ...                          ...
# 2875                                NaN  2024-02-01T10:55:24.768005Z
# 2876                                NaN  2024-02-01T10:55:45.123261Z
# 2877                                NaN  2024-02-01T10:55:54.827359Z
# 2878                                NaN  2024-02-01T10:56:01.892195Z
# 2879                                NaN  2024-02-01T10:56:26.382728Z
#
#      few_shot_condtion                                    id  \
# 0               random  a49a6f01-1ecc-4da0-b76b-f283f518fc60
# 1               random  d6c3769c-e06a-4b05-8ccf-e1338af83856
# 2               random  3772b851-5f3f-49a4-b456-dd1e8878abf4
# 3               random  011243dc-960f-4c73-8d8c-3c6238011f63
# 4               random  63a89c9b-458a-466b-89c3-462b9f1b1833
# ...                ...                                   ...
# 2875            random  547cf992-3416-4c7d-9574-6171afcde808
# 2876            random  5eaf80eb-759a-4a0b-bf27-09045e416368
# 2877            random  9b1b0342-df05-43d0-b374-0a69defe9629
# 2878            random  cd280c0b-e69c-41d9-af3f-7fd489898820
# 2879            random  1abe6a5e-f0a5-4fb2-80a7-c8e01737eded
#
#                                          label-explicit  \
# 0                                                   NaN
# 1     [{"end":9,"text":"Essen","start":4,"labels":["...
# 2                                                   NaN
# 3                                                   NaN
# 4     [{"end":14,"text":"Restaurant","start":4,"labe...
# ...                                                 ...
# 2875  [{"end":8,"text":"Ambiente","start":0,"labels"...
# 2876  [{"end":29,"text":"Essen","start":24,"labels":...
# 2877  [{"end":16,"text":"Service","start":9,"labels"...
# 2878  [{"end":9,"text":"Preis","start":4,"labels":["...
# 2879  [{"end":12,"text":"Ambiente","start":4,"labels...
#
#                                          label-implicit  lead_time     model  \
# 0     [{"end":25,"text":"waren sehr zufrieden.","sta...     14.011  Llama70B
# 1                                                   NaN     18.298  Llama70B
# 2     [{"end":37,"text":"was man bekommt","start":22...     18.566  Llama70B
# 3                                                   NaN     10.431  Llama70B
# 4                                                   NaN     10.857  Llama70B
# ...                                                 ...        ...       ...
# 2875                                                NaN      3.966  Llama70B
# 2876                                                NaN     19.498  Llama70B
# 2877                                                NaN      8.843  Llama70B
# 2878                                                NaN      6.223  Llama70B
# 2879                                                NaN     23.281  Llama70B
#
#       split                                               text  \
# 0         0                          Wir waren sehr zufrieden.
# 1         0  Das Essen war gut, aber der Service leider nicht.
# 2         0             Viel zu teuer für das was man bekommt.
# 3         0                       Wir waren schon öfters hier.
# 4         0            Das Restaurant ist sehr empfehlenswert.
# ...     ...                                                ...
# 2875      5                               Ambiente ordentlich.
# 2876      5  Bei den Preisen für das Essen und die Getränke...
# 2877      5  Aber der Service war schrecklich langsam und d...
# 2878      5                          Der Preis ist in Ordnung.
# 2879      5  Das Ambiente war sehr gemütlich und das Essen ...
#
#      two_or_more_sentences                   updated_at  Unnamed: 0
# 0                      NaN  2024-01-17T12:39:00.806355Z         NaN
# 1                      NaN  2024-01-17T12:39:20.055089Z         NaN
# 2                      NaN  2024-01-17T12:39:39.528712Z         NaN
# 3                      NaN  2024-01-17T12:39:50.874034Z         NaN
# 4                      NaN  2024-01-17T12:40:02.602362Z         NaN
# ...                    ...                          ...         ...
# 2875                   NaN  2024-02-01T10:55:24.768021Z       115.0
# 2876                   NaN  2024-02-01T10:55:45.123279Z       116.0
# 2877                   NaN  2024-02-01T10:55:54.827377Z       117.0
# 2878                   NaN  2024-02-01T10:56:01.892211Z       118.0
# 2879                   NaN  2024-02-01T10:56:26.382748Z       119.0
#
# [2880 rows x 16 columns]

# %%
df["second_annotator_comment"] = None
df["two_or_more_sentences"].unique()
# Out:
# array([nan, 'Two or more sentences'], dtype=object)

# %%
def merge_labels_implicit_to_explicit(dataframe):
    # Benutzerdefinierte Funktion, um label-implicit zu label-explicit hinzuzufügen und 'type' hinzufügen
    def merge_labels(row):
        labels_explicit = row["label-explicit"]
        labels_implicit = row["label-implicit"]

        if isinstance(labels_explicit, str) == False:
            labels_explicit = []
        else:
            labels_explicit = json.loads(labels_explicit)

        if isinstance(labels_implicit, str) == False:
            labels_implicit = []
        else:
            labels_implicit = json.loads(labels_implicit)

        labels_total = ""
        for annotation in labels_implicit:
            tuple = (annotation["labels"][0][:-len("-no-phrase")].rsplit('-', 1)[0],
                     annotation["labels"][0][:-len("-no-phrase")].rsplit('-', 1)[-1], 'NULL')
            labels_total += str(tuple) + "\n"

        for annotation in labels_explicit:
            tuple = (annotation["labels"][0].rsplit('-', 1)[0],
                     annotation["labels"][0].rsplit('-', 1)[-1], annotation["text"])
            labels_total += str(tuple) + "\n"

        row["annotation"] = labels_total

        # Sonderfälle
        # Update: Text is a bit misleading - my fault... However, I wanted to mark examples with mentioned aspects towards which no sentiment
        # was expressed by the author.
        if row["aspect_available_without_judgement"] == 'An aspect is addressed in the text without an explicit mention by the author':
            row["aspect_available_without_judgement"] = "✅"
        else:
            row["aspect_available_without_judgement"] = ""

        if row["two_or_more_sentences"] == "Two or more sentences":
            row["annotation"] = "⚠️ Mehr als 1 Satz im Text identifiziert von Annoator A"

        row["second_annotator_comment"] = ""
        return row

    dataframe = dataframe.apply(merge_labels, axis=1)

    return dataframe

# %%
total_rows = len(df)
rows_per_part = total_rows // N_PARTS

for idx in range(N_PARTS):
    start_idx = idx * rows_per_part
    end_idx = (idx + 1) * rows_per_part if idx < N_PARTS - 1 else total_rows
    part_df = df.iloc[start_idx:end_idx]

    filename = f"{OUTPUT_PATH_PREFIX}_{idx}.csv"

    part_df = merge_labels_implicit_to_explicit(part_df)
    part_df = part_df[["id", "second_annotator_comment", "annotation", "aspect_available_without_judgement", "text", "model", "few_shot_condtion", "split"]]

    part_df.to_csv(filename, index=False)

    print(f"Part {idx} saved to '{filename}'.")
# Out:
# Part 0 saved to 'annotation_datasets/annotation_jakob_0.csv'.

# %%
result_df = part_df[part_df.duplicated(subset=['text'], keep=False) & part_df.groupby('text')['annotation'].transform('nunique').gt(1)]
result_df[0:20]
# Out:
# Empty DataFrame
# Columns: [id, second_annotator_comment, annotation, aspect_available_without_judgement, text, model, few_shot_condtion, split]
# Index: []

# %%
for (text_value, model_value, few_shot_condition_value), group_df in result_df.groupby(['text', 'model', 'few_shot_condtion']):
    unique_annotation_values = group_df['annotation'].unique()
    print(f"Text: {text_value}, Model: {model_value}, Few Shot Condition: {few_shot_condition_value}, Possible Annotation Values: {', '.join(unique_annotation_values)}")

# %%
# Todo: Restaurant als aspekt begriff bei ambiente

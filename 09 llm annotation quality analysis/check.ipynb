# %%
import pandas as pd

file_path = "annotation_datasets/synth_annotation_labelstudio_input/annotation_Llama3_70B_random_600.csv"

data_df = pd.read_csv(file_path)

# %%
data_df
# Out:
#      Unnamed: 0                                    id  \
# 0             0  7c58ddc2-e88f-4792-8200-b5df69db0685
# 1             1  14e99323-54fd-450c-9b97-0385439c126c
# 2             2  fd18b2ee-f488-4500-b2e7-657d10a33593
# 3             3  fabc23ce-909c-4658-9736-c3b98f77dd3f
# 4             4  2ad10529-0f17-48a2-a000-d6b50e4fb2ee
# ..          ...                                   ...
# 595         595  2e5479e1-b082-46a2-bd81-51ba8db1f82c
# 596         596  2301f8bb-8da4-49fc-9c83-135e267af66c
# 597         597  d30a5d94-ed38-482f-b5f4-18dbce21322d
# 598         598  c3825862-3a4b-42e4-bbb8-a24fa8d37e0d
# 599         599  cfcbefea-0b64-407f-83ef-65b22f6f4194
#
#                                                   text       model  split  \
# 0              Das Restaurant hat eine tolle Location.  Llama3_70B      0
# 1     Die Atmosphäre war ok, die Bedienung eher nicht.  Llama3_70B      0
# 2    Die Preise, die für ein solches Essen verlangt...  Llama3_70B      0
# ...

# %%
import pandas as pd

# Annahme: data_df ist dein DataFrame

# Die häufigsten Werte in der Spalte "text" erhalten
häufigste_werte = data_df['text'].value_counts()

# Die Top N häufigsten Werte erhalten (z.B. die Top 5)
top_n_häufigste_werte = data_df['text'].value_counts().head(20)

# häufigste_werte und top_n_häufigste_werte sind Pandas Series mit den häufigsten Werten und ihren jeweiligen Häufigkeiten
top_n_häufigste_werte
# Out:
# Das Ambiente ist sehr schön und gemütlich.                  4
# Das Essen war sehr gut.                                     4
# Das Personal war sehr freundlich und zuvorkommend.          3
# Das Preis-Leistungsverhältnis ist sehr gut.                 3
# Die Preise sind zu hoch.                                    3
# Die Bedienung war freundlich und schnell.                   3
# Die Bedienung war sehr freundlich und zuvorkommend.         2
# Das Essen war lecker.                                       2
# Das Essen war nicht gut.                                    2
# Das Ambiente ist eher schlicht gehalten.                    2
# Das Personal war sehr freundlich und aufmerksam.            2
# Die Speisen sind durchschnittlich.                          2
# Die Bedienung war freundlich und aufmerksam.                2
# Das Essen war ok.                                           2
# Die Preise sind angemessen.                                 2
# ...
